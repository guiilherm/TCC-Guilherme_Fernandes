# %%
import os
import cv2
import random
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, cohen_kappa_score
import tensorflow as tf
import keras
from keras.models import Model
from keras import optimizers, applications
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import optimizers
from tensorflow.keras.applications import Xception, NASNetLarge, NASNetMobile, InceptionResNetV2,EfficientNetB0
from keras.layers import Dense, Dropout, GlobalAveragePooling2D, Input

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")

pd.options.display.max_colwidth = 100

# %%
data = pd.read_csv('../input/k-fold-new-data-sim-2/5-fold.csv')
test = pd.read_csv('../input/k-fold-new-data-sim-2/test.csv')

data['id_code'] = data['id_code'].apply(lambda x: x + '.jpg')
test['id_code'] = test['id_code'].apply(lambda x: x + '.jpg')

#fold 0
train_fold0 = data[data['fold_0'] == 'train'][['id_code','diagnosis']]
valid_fold0 = data[data['fold_0'] == 'validation'][['id_code','diagnosis']]

#fold 0
train_fold1 = data[data['fold_1'] == 'train'][['id_code','diagnosis']]
valid_fold1 = data[data['fold_1'] == 'validation'][['id_code','diagnosis']]

#fold 0
train_fold2 = data[data['fold_2'] == 'train'][['id_code','diagnosis']]
valid_fold2 = data[data['fold_2'] == 'validation'][['id_code','diagnosis']]

#fold 0
train_fold3 = data[data['fold_3'] == 'train'][['id_code','diagnosis']]
valid_fold3 = data[data['fold_3'] == 'validation'][['id_code','diagnosis']]

#fold 0
train_fold4 = data[data['fold_4'] == 'train'][['id_code','diagnosis']]
valid_fold4 = data[data['fold_4'] == 'validation'][['id_code','diagnosis']]

# %%
# Model parameters
BATCH_SIZE = 10
EPOCHS = 10
WARMUP_EPOCHS = 3
LEARNING_RATE = 1e-4
WARMUP_LEARNING_RATE = 1e-3
HEIGHT = 512
WIDTH = 512
CANAL = 3
N_CLASSES = train_fold0['diagnosis'].nunique()
ES_PATIENCE = 5
RLROP_PATIENCE = 3
DECAY_DROP = 0.5

metric_list = ["accuracy"]

# %%
def train_model(train_fold, valid_fold, fold):
    
    train_fold['diagnosis'] = train_fold['diagnosis'].astype(str)
    valid_fold['diagnosis'] = valid_fold['diagnosis'].astype(str)
    
    datagen=ImageDataGenerator(rescale=1./255, 
                           rotation_range=360,
                           horizontal_flip=True,
                           vertical_flip=True)

    train_generator=datagen.flow_from_dataframe(
                        dataframe=train_fold,
                        directory='../input/resized-2015-2019-blindness-detection-images/resized train 19',
                        x_col="id_code",
                        y_col="diagnosis",
                        class_mode="categorical",
                        batch_size=BATCH_SIZE,
                        target_size=(HEIGHT, WIDTH))

    valid_generator=datagen.flow_from_dataframe(
                        dataframe=valid_fold,
                        directory='../input/resized-2015-2019-blindness-detection-images/resized train 19',
                        x_col="id_code",
                        y_col="diagnosis",
                        class_mode="categorical",
                        batch_size=BATCH_SIZE,
                        target_size=(HEIGHT, WIDTH))

    test_generator=datagen.flow_from_dataframe(  
                       dataframe=test,
                       directory='../input/resized-2015-2019-blindness-detection-images/resized train 19',
                       x_col="id_code",
                       batch_size=1,
                       class_mode=None,
                       shuffle=False,
                       target_size=(HEIGHT, WIDTH))
    
    
    input_tensor = Input(shape=(HEIGHT, WIDTH, CANAL))
    base_model = Xception(weights='imagenet', 
                                       include_top=False,
                                       input_tensor=input_tensor)

    x = GlobalAveragePooling2D()(base_model.output)
    x = Dropout(0.5)(x)
    x = Dense(2048, activation='relu')(x)
    x = Dropout(0.5)(x)
    final_output = Dense(5, activation='softmax', name='final_output')(x)
    model = Model(input_tensor, final_output)
    
    for layer in model.layers:
        layer.trainable = False

    for i in range(-5, 0):
        model.layers[i].trainable = True

    metric_list = ["accuracy"]
    optimizer = tf.keras.optimizers.Adam(lr=WARMUP_LEARNING_RATE)
    model.compile(optimizer=optimizer, loss="categorical_crossentropy",  metrics=metric_list)
    
    STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
    STEP_SIZE_VALID = valid_generator.n//valid_generator.batch_size

    history_warmup = model.fit(train_generator,
                                     validation_data=valid_generator,
                                     steps_per_epoch=STEP_SIZE_TRAIN,
                                     validation_steps=STEP_SIZE_VALID,
                                     epochs=15,
                                     verbose=1).history
    
    for layer in model.layers:
        layer.trainable = True

    es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
    rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-6, verbose=1)

    callback_list = [es, rlrop]
    optimizer = tf.keras.optimizers.Adam(lr=LEARNING_RATE)
    model.compile(optimizer=optimizer, loss="categorical_crossentropy",  metrics=metric_list)
    
    history_finetunning = model.fit_generator(generator=train_generator,
                                          steps_per_epoch=STEP_SIZE_TRAIN,
                                          validation_data=valid_generator,
                                          validation_steps=STEP_SIZE_VALID,
                                          epochs=40,
                                          callbacks=callback_list,
                                          verbose=1).history
    
    model.save('Xception-'+fold+'sim1.h5')
    
    history = {'loss': history_warmup['loss'] + history_finetunning['loss'], 
               'val_loss': history_warmup['val_loss'] + history_finetunning['val_loss'], 
               'acc': history_warmup['accuracy'] + history_finetunning['accuracy'], 
               'val_acc': history_warmup['val_accuracy'] + history_finetunning['val_accuracy']}

    sns.set_style("whitegrid")
    fig, (ax1, ax2) = plt.subplots(2, 1, sharex='col', figsize=(20, 14))

    ax1.plot(history['loss'], label='Train loss')
    ax1.plot(history['val_loss'], label='Validation loss')
    ax1.legend(loc='best')
    ax1.set_title('Loss')
    plt.ylim([0,1])
    ax2.plot(history['acc'], label='Train Accuracy')
    ax2.plot(history['val_acc'], label='Validation Accuracy')
    ax2.legend(loc='best')
    ax2.set_title('Accuracy')
    ax2.set_ylim([0,1])
    plt.xlabel('Epochs')


    sns.despine()
    fig.savefig('acc-loss-'+fold)
    
    complete_datagen = ImageDataGenerator(rescale=1./255)
    complete_generator = complete_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/resized-2015-2019-blindness-detection-images/resized train 19",
        x_col="id_code",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)

    STEP_SIZE_COMPLETE = complete_generator.n//complete_generator.batch_size
    train_preds = model.predict_generator(complete_generator, steps=STEP_SIZE_COMPLETE)
    train_preds = [np.argmax(pred) for pred in train_preds]

    
    labels = ['0 - No DR', '1 - Mild', '2 - Moderate', '3 - Severe', '4 - Proliferative DR']
    cnf_matrix = confusion_matrix(test['diagnosis'].astype('int'), train_preds)
    cnf_matrix_norm = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    df_cm = pd.DataFrame(cnf_matrix_norm, index=labels, columns=labels)
    plt.figure(figsize=(16, 7))
    heatmap = sns.heatmap(df_cm, annot=True, fmt='.2f', cmap="Blues")
    heatmap = heatmap.get_figure()
    heatmap.savefig('heatmap-'+fold)
    
    print(fold+" - Train Cohen Kappa score: %.3f" % cohen_kappa_score(train_preds, test['diagnosis'].astype('int'), weights='quadratic'))

# %%
train_model(train_fold0, valid_fold0, 'FOLD0')
train_model(train_fold1, valid_fold1, 'FOLD1')
train_model(train_fold2, valid_fold2, 'FOLD2')
train_model(train_fold3, valid_fold3, 'FOLD3')
train_model(train_fold4, valid_fold4, 'FOLD4')
# Out:
# Found 2050 validated image filenames belonging to 5 classes.
# Found 513 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames.
# 2022-07-23 01:13:01.695005: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 01:13:01.796655: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 01:13:01.797608: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 01:13:01.799165: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-23 01:13:01.800347: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 01:13:01.801029: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 01:13:01.801697: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 01:13:03.908595: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 01:13:03.909515: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 01:13:03.910267: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 01:13:03.910862: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step
# 83697664/83683744 [==============================] - 1s 0us/step
# 2022-07-23 01:13:07.714585: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/15
# 2022-07-23 01:13:11.762421: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 205/205 [==============================] - 192s 893ms/step - loss: 0.9359 - accuracy: 0.6800 - val_loss: 0.6647 - val_accuracy: 0.7392
# Epoch 2/15
# 205/205 [==============================] - 172s 840ms/step - loss: 0.7956 - accuracy: 0.7078 - val_loss: 0.6460 - val_accuracy: 0.7529
# Epoch 3/15
# 205/205 [==============================] - 167s 816ms/step - loss: 0.7362 - accuracy: 0.7263 - val_loss: 0.6056 - val_accuracy: 0.7725
# Epoch 4/15
# 205/205 [==============================] - 168s 822ms/step - loss: 0.7161 - accuracy: 0.7371 - val_loss: 0.5870 - val_accuracy: 0.7804
# Epoch 5/15
# 205/205 [==============================] - 172s 835ms/step - loss: 0.7037 - accuracy: 0.7434 - val_loss: 0.6091 - val_accuracy: 0.7725
# Epoch 6/15
# 205/205 [==============================] - 171s 834ms/step - loss: 0.6850 - accuracy: 0.7493 - val_loss: 0.6034 - val_accuracy: 0.7745
# Epoch 7/15
# 205/205 [==============================] - 178s 866ms/step - loss: 0.6764 - accuracy: 0.7537 - val_loss: 0.6010 - val_accuracy: 0.7627
# Epoch 8/15
# 205/205 [==============================] - 174s 847ms/step - loss: 0.6952 - accuracy: 0.7410 - val_loss: 0.5689 - val_accuracy: 0.7745
# Epoch 9/15
# 205/205 [==============================] - 170s 826ms/step - loss: 0.6819 - accuracy: 0.7463 - val_loss: 0.5817 - val_accuracy: 0.7588
# Epoch 10/15
# 205/205 [==============================] - 174s 848ms/step - loss: 0.6709 - accuracy: 0.7424 - val_loss: 0.5715 - val_accuracy: 0.7725
# Epoch 11/15
# 205/205 [==============================] - 168s 821ms/step - loss: 0.6845 - accuracy: 0.7493 - val_loss: 0.5805 - val_accuracy: 0.7824
# Epoch 12/15
# 205/205 [==============================] - 171s 834ms/step - loss: 0.6567 - accuracy: 0.7429 - val_loss: 0.6070 - val_accuracy: 0.7824
# Epoch 13/15
# 205/205 [==============================] - 173s 840ms/step - loss: 0.6469 - accuracy: 0.7551 - val_loss: 0.5929 - val_accuracy: 0.7667
# Epoch 14/15
# 205/205 [==============================] - 171s 834ms/step - loss: 0.6533 - accuracy: 0.7585 - val_loss: 0.5606 - val_accuracy: 0.7686
# Epoch 15/15
# 205/205 [==============================] - 172s 835ms/step - loss: 0.6524 - accuracy: 0.7605 - val_loss: 0.5520 - val_accuracy: 0.7667
# Epoch 1/40
# 205/205 [==============================] - 225s 1s/step - loss: 0.9167 - accuracy: 0.6844 - val_loss: 0.5766 - val_accuracy: 0.7765
# Epoch 2/40
# 205/205 [==============================] - 218s 1s/step - loss: 0.6524 - accuracy: 0.7663 - val_loss: 0.5815 - val_accuracy: 0.7824
# Epoch 3/40
# 205/205 [==============================] - 219s 1s/step - loss: 0.5415 - accuracy: 0.8034 - val_loss: 0.4752 - val_accuracy: 0.8235
# Epoch 4/40
# 205/205 [==============================] - 218s 1s/step - loss: 0.5128 - accuracy: 0.8112 - val_loss: 0.4857 - val_accuracy: 0.8196
# Epoch 5/40
# 205/205 [==============================] - 220s 1s/step - loss: 0.4657 - accuracy: 0.8249 - val_loss: 0.4867 - val_accuracy: 0.8255
# Epoch 6/40
# 205/205 [==============================] - 225s 1s/step - loss: 0.4392 - accuracy: 0.8259 - val_loss: 0.4692 - val_accuracy: 0.8275
# Epoch 7/40
# 205/205 [==============================] - 223s 1s/step - loss: 0.4085 - accuracy: 0.8327 - val_loss: 0.4842 - val_accuracy: 0.8294
# Epoch 8/40
# 205/205 [==============================] - 220s 1s/step - loss: 0.4138 - accuracy: 0.8493 - val_loss: 0.4509 - val_accuracy: 0.8373
# Epoch 9/40
# 205/205 [==============================] - 223s 1s/step - loss: 0.3580 - accuracy: 0.8585 - val_loss: 0.5273 - val_accuracy: 0.8078
# Epoch 10/40
# 205/205 [==============================] - 225s 1s/step - loss: 0.3527 - accuracy: 0.8629 - val_loss: 0.5085 - val_accuracy: 0.8333
# Epoch 11/40
# 205/205 [==============================] - 224s 1s/step - loss: 0.3227 - accuracy: 0.8810 - val_loss: 0.5695 - val_accuracy: 0.7941
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 12/40
# 205/205 [==============================] - 222s 1s/step - loss: 0.2594 - accuracy: 0.9015 - val_loss: 0.4660 - val_accuracy: 0.8392
# Epoch 13/40
# 205/205 [==============================] - 220s 1s/step - loss: 0.2605 - accuracy: 0.9005 - val_loss: 0.5141 - val_accuracy: 0.8569
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping
# Found 733 validated image filenames.
# FOLD0 - Train Cohen Kappa score: 0.897
# Found 2050 validated image filenames belonging to 5 classes.
# Found 513 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames.
# Epoch 1/15
# 205/205 [==============================] - 171s 827ms/step - loss: 0.9520 - accuracy: 0.6732 - val_loss: 0.7816 - val_accuracy: 0.7333
# Epoch 2/15
# 205/205 [==============================] - 170s 829ms/step - loss: 0.8022 - accuracy: 0.6966 - val_loss: 0.6734 - val_accuracy: 0.7431
# Epoch 3/15
# 205/205 [==============================] - 170s 829ms/step - loss: 0.7367 - accuracy: 0.7156 - val_loss: 0.6519 - val_accuracy: 0.7392
# Epoch 4/15
# 205/205 [==============================] - 172s 837ms/step - loss: 0.7164 - accuracy: 0.7249 - val_loss: 0.5979 - val_accuracy: 0.7824
# Epoch 5/15
# 205/205 [==============================] - 171s 834ms/step - loss: 0.6964 - accuracy: 0.7356 - val_loss: 0.6478 - val_accuracy: 0.7686
# Epoch 6/15
# 205/205 [==============================] - 172s 837ms/step - loss: 0.6850 - accuracy: 0.7434 - val_loss: 0.6383 - val_accuracy: 0.7510
# Epoch 7/15
# 205/205 [==============================] - 171s 834ms/step - loss: 0.6788 - accuracy: 0.7493 - val_loss: 0.6170 - val_accuracy: 0.7706
# Epoch 8/15
# 205/205 [==============================] - 174s 847ms/step - loss: 0.6603 - accuracy: 0.7415 - val_loss: 0.6876 - val_accuracy: 0.7549
# Epoch 9/15
# 205/205 [==============================] - 173s 843ms/step - loss: 0.6611 - accuracy: 0.7415 - val_loss: 0.6893 - val_accuracy: 0.7294
# Epoch 10/15
# 205/205 [==============================] - 173s 844ms/step - loss: 0.6529 - accuracy: 0.7463 - val_loss: 0.6283 - val_accuracy: 0.7824
# Epoch 11/15
# 205/205 [==============================] - 173s 843ms/step - loss: 0.6405 - accuracy: 0.7493 - val_loss: 0.6172 - val_accuracy: 0.7608
# Epoch 12/15
# 205/205 [==============================] - 173s 843ms/step - loss: 0.6496 - accuracy: 0.7429 - val_loss: 0.6091 - val_accuracy: 0.7765
# Epoch 13/15
# 205/205 [==============================] - 176s 858ms/step - loss: 0.6342 - accuracy: 0.7595 - val_loss: 0.6344 - val_accuracy: 0.7471
# Epoch 14/15
# 205/205 [==============================] - 175s 852ms/step - loss: 0.6312 - accuracy: 0.7610 - val_loss: 0.6065 - val_accuracy: 0.7745
# Epoch 15/15
# 205/205 [==============================] - 173s 840ms/step - loss: 0.6410 - accuracy: 0.7571 - val_loss: 0.6025 - val_accuracy: 0.7824
# Epoch 1/40
# 205/205 [==============================] - 231s 1s/step - loss: 0.8561 - accuracy: 0.6990 - val_loss: 0.6083 - val_accuracy: 0.7725
# Epoch 2/40
# 205/205 [==============================] - 222s 1s/step - loss: 0.6311 - accuracy: 0.7683 - val_loss: 0.5696 - val_accuracy: 0.7980
# Epoch 3/40
# 205/205 [==============================] - 222s 1s/step - loss: 0.5446 - accuracy: 0.7951 - val_loss: 0.5323 - val_accuracy: 0.7941
# Epoch 4/40
# 205/205 [==============================] - 223s 1s/step - loss: 0.5005 - accuracy: 0.8122 - val_loss: 0.5971 - val_accuracy: 0.7882
# Epoch 5/40
# 205/205 [==============================] - 224s 1s/step - loss: 0.4589 - accuracy: 0.8234 - val_loss: 0.4606 - val_accuracy: 0.8255
# Epoch 6/40
# 205/205 [==============================] - 228s 1s/step - loss: 0.4212 - accuracy: 0.8351 - val_loss: 0.5142 - val_accuracy: 0.7804
# Epoch 7/40
# 205/205 [==============================] - 229s 1s/step - loss: 0.4109 - accuracy: 0.8395 - val_loss: 0.5152 - val_accuracy: 0.8255
# Epoch 8/40
# 205/205 [==============================] - 226s 1s/step - loss: 0.3815 - accuracy: 0.8522 - val_loss: 0.4725 - val_accuracy: 0.8294
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 9/40
# 205/205 [==============================] - 229s 1s/step - loss: 0.3151 - accuracy: 0.8776 - val_loss: 0.5165 - val_accuracy: 0.8353
# Epoch 10/40
# 205/205 [==============================] - 226s 1s/step - loss: 0.2941 - accuracy: 0.8907 - val_loss: 0.5450 - val_accuracy: 0.8039
# Restoring model weights from the end of the best epoch.
# Epoch 00010: early stopping
# Found 733 validated image filenames.
# FOLD1 - Train Cohen Kappa score: 0.878
# Found 2050 validated image filenames belonging to 5 classes.
# Found 513 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames.
# Epoch 1/15
# 205/205 [==============================] - 178s 861ms/step - loss: 0.9578 - accuracy: 0.6585 - val_loss: 0.6986 - val_accuracy: 0.7373
# Epoch 2/15
# 205/205 [==============================] - 176s 857ms/step - loss: 0.7557 - accuracy: 0.7244 - val_loss: 0.6595 - val_accuracy: 0.7255
# Epoch 3/15
# 205/205 [==============================] - 176s 857ms/step - loss: 0.7451 - accuracy: 0.7180 - val_loss: 0.6803 - val_accuracy: 0.7392
# Epoch 4/15
# 205/205 [==============================] - 176s 856ms/step - loss: 0.7294 - accuracy: 0.7337 - val_loss: 0.7006 - val_accuracy: 0.7098
# Epoch 5/15
# 205/205 [==============================] - 176s 861ms/step - loss: 0.6657 - accuracy: 0.7463 - val_loss: 0.7042 - val_accuracy: 0.7471
# Epoch 6/15
# 205/205 [==============================] - 175s 856ms/step - loss: 0.6752 - accuracy: 0.7498 - val_loss: 0.6341 - val_accuracy: 0.7725
# Epoch 7/15
# 205/205 [==============================] - 176s 857ms/step - loss: 0.6918 - accuracy: 0.7444 - val_loss: 0.6013 - val_accuracy: 0.7765
# Epoch 8/15
# 205/205 [==============================] - 177s 863ms/step - loss: 0.6745 - accuracy: 0.7512 - val_loss: 0.6363 - val_accuracy: 0.7647
# Epoch 9/15
# 205/205 [==============================] - 180s 875ms/step - loss: 0.6487 - accuracy: 0.7498 - val_loss: 0.6876 - val_accuracy: 0.7392
# Epoch 10/15
# 205/205 [==============================] - 171s 834ms/step - loss: 0.6276 - accuracy: 0.7600 - val_loss: 0.6646 - val_accuracy: 0.7490
# Epoch 11/15
# 205/205 [==============================] - 170s 829ms/step - loss: 0.6506 - accuracy: 0.7483 - val_loss: 0.6179 - val_accuracy: 0.7667
# Epoch 12/15
# 205/205 [==============================] - 170s 831ms/step - loss: 0.6389 - accuracy: 0.7468 - val_loss: 0.6236 - val_accuracy: 0.7588
# Epoch 13/15
# 205/205 [==============================] - 170s 832ms/step - loss: 0.6232 - accuracy: 0.7595 - val_loss: 0.6225 - val_accuracy: 0.7549
# Epoch 14/15
# 205/205 [==============================] - 174s 847ms/step - loss: 0.6305 - accuracy: 0.7644 - val_loss: 0.6382 - val_accuracy: 0.7451
# Epoch 15/15
# 205/205 [==============================] - 172s 840ms/step - loss: 0.6197 - accuracy: 0.7722 - val_loss: 0.6113 - val_accuracy: 0.7784
# Epoch 1/40
# 205/205 [==============================] - 229s 1s/step - loss: 0.8389 - accuracy: 0.7020 - val_loss: 0.5968 - val_accuracy: 0.7804
# Epoch 2/40
# 205/205 [==============================] - 229s 1s/step - loss: 0.6080 - accuracy: 0.7727 - val_loss: 0.5477 - val_accuracy: 0.7980
# Epoch 3/40
# 205/205 [==============================] - 224s 1s/step - loss: 0.5442 - accuracy: 0.7937 - val_loss: 0.5380 - val_accuracy: 0.7843
# Epoch 4/40
# 205/205 [==============================] - 225s 1s/step - loss: 0.5106 - accuracy: 0.8049 - val_loss: 0.5188 - val_accuracy: 0.8000
# Epoch 5/40
# 205/205 [==============================] - 222s 1s/step - loss: 0.4762 - accuracy: 0.8239 - val_loss: 0.6227 - val_accuracy: 0.8059
# Epoch 6/40
# 205/205 [==============================] - 225s 1s/step - loss: 0.4499 - accuracy: 0.8361 - val_loss: 0.4933 - val_accuracy: 0.8118
# Epoch 7/40
# 205/205 [==============================] - 226s 1s/step - loss: 0.4054 - accuracy: 0.8444 - val_loss: 0.4439 - val_accuracy: 0.8118
# Epoch 8/40
# 205/205 [==============================] - 234s 1s/step - loss: 0.3775 - accuracy: 0.8498 - val_loss: 0.4852 - val_accuracy: 0.8216
# Epoch 9/40
# 205/205 [==============================] - 232s 1s/step - loss: 0.3706 - accuracy: 0.8629 - val_loss: 0.5119 - val_accuracy: 0.7863
# Epoch 10/40
# 205/205 [==============================] - 232s 1s/step - loss: 0.3427 - accuracy: 0.8776 - val_loss: 0.4971 - val_accuracy: 0.8294
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 11/40
# 205/205 [==============================] - 231s 1s/step - loss: 0.2837 - accuracy: 0.8937 - val_loss: 0.5411 - val_accuracy: 0.8255
# Epoch 12/40
# 205/205 [==============================] - 232s 1s/step - loss: 0.2586 - accuracy: 0.9005 - val_loss: 0.4526 - val_accuracy: 0.8451
# Restoring model weights from the end of the best epoch.
# Epoch 00012: early stopping
# Found 733 validated image filenames.
# FOLD2 - Train Cohen Kappa score: 0.895
# Found 2051 validated image filenames belonging to 5 classes.
# Found 512 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames.
# Epoch 1/15
# 205/205 [==============================] - 186s 898ms/step - loss: 0.9442 - accuracy: 0.6624 - val_loss: 0.7501 - val_accuracy: 0.7412
# Epoch 2/15
# 205/205 [==============================] - 186s 907ms/step - loss: 0.8012 - accuracy: 0.7001 - val_loss: 0.6663 - val_accuracy: 0.7412
# Epoch 3/15
# 205/205 [==============================] - 183s 894ms/step - loss: 0.7510 - accuracy: 0.7222 - val_loss: 0.6309 - val_accuracy: 0.7569
# Epoch 4/15
# 205/205 [==============================] - 182s 889ms/step - loss: 0.7079 - accuracy: 0.7305 - val_loss: 0.6375 - val_accuracy: 0.7627
# Epoch 5/15
# 205/205 [==============================] - 184s 897ms/step - loss: 0.6995 - accuracy: 0.7384 - val_loss: 0.7190 - val_accuracy: 0.7275
# Epoch 6/15
# 205/205 [==============================] - 182s 889ms/step - loss: 0.6831 - accuracy: 0.7472 - val_loss: 0.5987 - val_accuracy: 0.7804
# Epoch 7/15
# 205/205 [==============================] - 179s 874ms/step - loss: 0.6964 - accuracy: 0.7359 - val_loss: 0.6190 - val_accuracy: 0.7667
# Epoch 8/15
# 205/205 [==============================] - 185s 903ms/step - loss: 0.6876 - accuracy: 0.7428 - val_loss: 0.5935 - val_accuracy: 0.7843
# Epoch 9/15
# 205/205 [==============================] - 175s 856ms/step - loss: 0.6651 - accuracy: 0.7442 - val_loss: 0.6122 - val_accuracy: 0.7725
# Epoch 10/15
# 205/205 [==============================] - 176s 859ms/step - loss: 0.6496 - accuracy: 0.7462 - val_loss: 0.5815 - val_accuracy: 0.7647
# Epoch 11/15
# 205/205 [==============================] - 179s 872ms/step - loss: 0.6471 - accuracy: 0.7521 - val_loss: 0.5870 - val_accuracy: 0.7765
# Epoch 12/15
# 205/205 [==============================] - 173s 843ms/step - loss: 0.6479 - accuracy: 0.7511 - val_loss: 0.6399 - val_accuracy: 0.7725
# Epoch 13/15
# 205/205 [==============================] - 172s 842ms/step - loss: 0.6423 - accuracy: 0.7570 - val_loss: 0.6063 - val_accuracy: 0.7745
# Epoch 14/15
# 205/205 [==============================] - 175s 856ms/step - loss: 0.6366 - accuracy: 0.7624 - val_loss: 0.5775 - val_accuracy: 0.7824
# Epoch 15/15
# 205/205 [==============================] - 174s 847ms/step - loss: 0.6536 - accuracy: 0.7511 - val_loss: 0.5705 - val_accuracy: 0.7941
# Epoch 1/40
# 205/205 [==============================] - 229s 1s/step - loss: 0.8874 - accuracy: 0.6850 - val_loss: 0.5499 - val_accuracy: 0.7784
# Epoch 2/40
# 205/205 [==============================] - 226s 1s/step - loss: 0.6197 - accuracy: 0.7697 - val_loss: 0.5530 - val_accuracy: 0.7882
# Epoch 3/40
# 205/205 [==============================] - 226s 1s/step - loss: 0.5446 - accuracy: 0.7967 - val_loss: 0.5252 - val_accuracy: 0.8235
# Epoch 4/40
# 205/205 [==============================] - 225s 1s/step - loss: 0.5156 - accuracy: 0.8143 - val_loss: 0.5309 - val_accuracy: 0.8000
# Epoch 5/40
# 205/205 [==============================] - 227s 1s/step - loss: 0.4750 - accuracy: 0.8270 - val_loss: 0.4889 - val_accuracy: 0.8235
# Epoch 6/40
# 205/205 [==============================] - 227s 1s/step - loss: 0.4175 - accuracy: 0.8447 - val_loss: 0.4958 - val_accuracy: 0.8078
# Epoch 7/40
# 205/205 [==============================] - 226s 1s/step - loss: 0.4075 - accuracy: 0.8511 - val_loss: 0.4895 - val_accuracy: 0.8255
# Epoch 8/40
# 205/205 [==============================] - 229s 1s/step - loss: 0.3580 - accuracy: 0.8692 - val_loss: 0.5217 - val_accuracy: 0.8333
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 9/40
# 205/205 [==============================] - 226s 1s/step - loss: 0.3063 - accuracy: 0.8849 - val_loss: 0.5771 - val_accuracy: 0.8275
# Epoch 10/40
# 205/205 [==============================] - 227s 1s/step - loss: 0.2853 - accuracy: 0.8932 - val_loss: 0.5426 - val_accuracy: 0.8216
# Restoring model weights from the end of the best epoch.
# Epoch 00010: early stopping
# Found 733 validated image filenames.
# FOLD3 - Train Cohen Kappa score: 0.863
# Found 2051 validated image filenames belonging to 5 classes.
# Found 512 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames.
# Epoch 1/15
# 205/205 [==============================] - 177s 853ms/step - loss: 0.9696 - accuracy: 0.6634 - val_loss: 0.6577 - val_accuracy: 0.7529
# Epoch 2/15
# 205/205 [==============================] - 176s 856ms/step - loss: 0.7799 - accuracy: 0.7178 - val_loss: 0.7056 - val_accuracy: 0.7627
# Epoch 3/15
# 205/205 [==============================] - 173s 846ms/step - loss: 0.7414 - accuracy: 0.7139 - val_loss: 0.6264 - val_accuracy: 0.7706
# Epoch 4/15
# 205/205 [==============================] - 176s 858ms/step - loss: 0.7127 - accuracy: 0.7271 - val_loss: 0.6224 - val_accuracy: 0.7627
# Epoch 5/15
# 205/205 [==============================] - 176s 858ms/step - loss: 0.7140 - accuracy: 0.7281 - val_loss: 0.6420 - val_accuracy: 0.7471
# Epoch 6/15
# 205/205 [==============================] - 178s 869ms/step - loss: 0.6875 - accuracy: 0.7433 - val_loss: 0.6462 - val_accuracy: 0.7725
# Epoch 7/15
# 205/205 [==============================] - 175s 856ms/step - loss: 0.6752 - accuracy: 0.7364 - val_loss: 0.6180 - val_accuracy: 0.7706
# Epoch 8/15
# 205/205 [==============================] - 176s 860ms/step - loss: 0.6896 - accuracy: 0.7442 - val_loss: 0.5934 - val_accuracy: 0.7824
# Epoch 9/15
# 205/205 [==============================] - 176s 855ms/step - loss: 0.6694 - accuracy: 0.7467 - val_loss: 0.5812 - val_accuracy: 0.7647
# Epoch 10/15
# 205/205 [==============================] - 175s 856ms/step - loss: 0.6400 - accuracy: 0.7575 - val_loss: 0.5759 - val_accuracy: 0.7863
# Epoch 11/15
# 205/205 [==============================] - 175s 856ms/step - loss: 0.6668 - accuracy: 0.7496 - val_loss: 0.6358 - val_accuracy: 0.7686
# Epoch 12/15
# 205/205 [==============================] - 178s 871ms/step - loss: 0.6381 - accuracy: 0.7609 - val_loss: 0.5964 - val_accuracy: 0.7686
# Epoch 13/15
# 205/205 [==============================] - 179s 871ms/step - loss: 0.6594 - accuracy: 0.7550 - val_loss: 0.6490 - val_accuracy: 0.7608
# Epoch 14/15
# 205/205 [==============================] - 177s 860ms/step - loss: 0.6432 - accuracy: 0.7506 - val_loss: 0.6500 - val_accuracy: 0.7588
# Epoch 15/15
# 205/205 [==============================] - 176s 857ms/step - loss: 0.6364 - accuracy: 0.7589 - val_loss: 0.5953 - val_accuracy: 0.7706
# Epoch 1/40
# 205/205 [==============================] - 235s 1s/step - loss: 0.8630 - accuracy: 0.6879 - val_loss: 0.6461 - val_accuracy: 0.7392
# Epoch 2/40
# 205/205 [==============================] - 224s 1s/step - loss: 0.6383 - accuracy: 0.7683 - val_loss: 0.5176 - val_accuracy: 0.8196
# Epoch 3/40
# 205/205 [==============================] - 226s 1s/step - loss: 0.5351 - accuracy: 0.8055 - val_loss: 0.4635 - val_accuracy: 0.8275
# Epoch 4/40
# 205/205 [==============================] - 228s 1s/step - loss: 0.4949 - accuracy: 0.8070 - val_loss: 0.4596 - val_accuracy: 0.8157
# Epoch 5/40
# 205/205 [==============================] - 220s 1s/step - loss: 0.4436 - accuracy: 0.8300 - val_loss: 0.4584 - val_accuracy: 0.8314
# Epoch 6/40
# 205/205 [==============================] - 221s 1s/step - loss: 0.4471 - accuracy: 0.8344 - val_loss: 0.4374 - val_accuracy: 0.8510
# Epoch 7/40
# 205/205 [==============================] - 226s 1s/step - loss: 0.4121 - accuracy: 0.8466 - val_loss: 0.4333 - val_accuracy: 0.8412
# Epoch 8/40
# 205/205 [==============================] - 225s 1s/step - loss: 0.3835 - accuracy: 0.8564 - val_loss: 0.4754 - val_accuracy: 0.8294
# Epoch 9/40
# 205/205 [==============================] - 218s 1s/step - loss: 0.3526 - accuracy: 0.8677 - val_loss: 0.4871 - val_accuracy: 0.8373
# Epoch 10/40
# 205/205 [==============================] - 224s 1s/step - loss: 0.3408 - accuracy: 0.8667 - val_loss: 0.5421 - val_accuracy: 0.8314
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 11/40
# 205/205 [==============================] - 224s 1s/step - loss: 0.2871 - accuracy: 0.8917 - val_loss: 0.4517 - val_accuracy: 0.8353
# Epoch 12/40
# 205/205 [==============================] - 221s 1s/step - loss: 0.2597 - accuracy: 0.9025 - val_loss: 0.4741 - val_accuracy: 0.8098
# Restoring model weights from the end of the best epoch.
# Epoch 00012: early stopping
# Found 733 validated image filenames.
# FOLD4 - Train Cohen Kappa score: 0.895
