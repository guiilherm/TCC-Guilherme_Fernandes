# %%
import os
import cv2
import random
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, cohen_kappa_score
import tensorflow as tf
import keras
from keras.models import Model
from keras import optimizers, applications
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import optimizers
from tensorflow.keras.applications import Xception, NASNetLarge, NASNetMobile, InceptionResNetV2,EfficientNetB0
from keras.layers import Dense, Dropout, GlobalAveragePooling2D, Input

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")

pd.options.display.max_colwidth = 100

# %%
data = pd.read_csv('../input/k-fold-new-data-sim-2/5-fold.csv')
test = pd.read_csv('../input/k-fold-new-data-sim-2/test.csv')

data['id_code'] = data['id_code'].apply(lambda x: x + '.jpg')
test['id_code'] = test['id_code'].apply(lambda x: x + '.jpg')

#fold 0
train_fold0 = data[data['fold_0'] == 'train'][['id_code','diagnosis']]
valid_fold0 = data[data['fold_0'] == 'validation'][['id_code','diagnosis']]

#fold 0
train_fold1 = data[data['fold_1'] == 'train'][['id_code','diagnosis']]
valid_fold1 = data[data['fold_1'] == 'validation'][['id_code','diagnosis']]

#fold 0
train_fold2 = data[data['fold_2'] == 'train'][['id_code','diagnosis']]
valid_fold2 = data[data['fold_2'] == 'validation'][['id_code','diagnosis']]

#fold 0
train_fold3 = data[data['fold_3'] == 'train'][['id_code','diagnosis']]
valid_fold3 = data[data['fold_3'] == 'validation'][['id_code','diagnosis']]

#fold 0
train_fold4 = data[data['fold_4'] == 'train'][['id_code','diagnosis']]
valid_fold4 = data[data['fold_4'] == 'validation'][['id_code','diagnosis']]

# %%
# Model parameters
BATCH_SIZE = 10
EPOCHS = 10
WARMUP_EPOCHS = 3
LEARNING_RATE = 1e-4
WARMUP_LEARNING_RATE = 1e-3
HEIGHT = 512
WIDTH = 512
CANAL = 3
N_CLASSES = train_fold0['diagnosis'].nunique()
ES_PATIENCE = 5
RLROP_PATIENCE = 3
DECAY_DROP = 0.5

metric_list = ["accuracy"]

# %%
def train_model(train_fold, valid_fold, fold):
    
    train_fold['diagnosis'] = train_fold['diagnosis'].astype(str)
    valid_fold['diagnosis'] = valid_fold['diagnosis'].astype(str)
    
    datagen=ImageDataGenerator(rescale=1./255, 
                           rotation_range=360,
                           horizontal_flip=True,
                           vertical_flip=True)

    train_generator=datagen.flow_from_dataframe(
                        dataframe=train_fold,
                        directory='../input/resized-2015-2019-blindness-detection-images/resized train 19',
                        x_col="id_code",
                        y_col="diagnosis",
                        class_mode="categorical",
                        batch_size=BATCH_SIZE,
                        target_size=(HEIGHT, WIDTH))

    valid_generator=datagen.flow_from_dataframe(
                        dataframe=valid_fold,
                        directory='../input/resized-2015-2019-blindness-detection-images/resized train 19',
                        x_col="id_code",
                        y_col="diagnosis",
                        class_mode="categorical",
                        batch_size=BATCH_SIZE,
                        target_size=(HEIGHT, WIDTH))

    test_generator=datagen.flow_from_dataframe(  
                       dataframe=test,
                       directory='../input/resized-2015-2019-blindness-detection-images/resized train 19',
                       x_col="id_code",
                       batch_size=1,
                       class_mode=None,
                       shuffle=False,
                       target_size=(HEIGHT, WIDTH))
    
    
    input_tensor = Input(shape=(HEIGHT, WIDTH, CANAL))
    base_model = EfficientNetB0(weights='imagenet', 
                                       include_top=False,
                                       input_tensor=input_tensor)

    x = GlobalAveragePooling2D()(base_model.output)
    x = Dropout(0.5)(x)
    x = Dense(2048, activation='relu')(x)
    x = Dropout(0.5)(x)
    final_output = Dense(5, activation='softmax', name='final_output')(x)
    model = Model(input_tensor, final_output)
    
    for layer in model.layers:
        layer.trainable = False

    for i in range(-5, 0):
        model.layers[i].trainable = True

    metric_list = ["accuracy"]
    optimizer = tf.keras.optimizers.Adam(lr=WARMUP_LEARNING_RATE)
    model.compile(optimizer=optimizer, loss="categorical_crossentropy",  metrics=metric_list)
    
    STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
    STEP_SIZE_VALID = valid_generator.n//valid_generator.batch_size

    history_warmup = model.fit(train_generator,
                                     validation_data=valid_generator,
                                     steps_per_epoch=STEP_SIZE_TRAIN,
                                     validation_steps=STEP_SIZE_VALID,
                                     epochs=15,
                                     verbose=1).history
    
    for layer in model.layers:
        layer.trainable = True

    es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
    rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-6, verbose=1)

    callback_list = [es, rlrop]
    optimizer = tf.keras.optimizers.Adam(lr=LEARNING_RATE)
    model.compile(optimizer=optimizer, loss="categorical_crossentropy",  metrics=metric_list)
    
    history_finetunning = model.fit_generator(generator=train_generator,
                                          steps_per_epoch=STEP_SIZE_TRAIN,
                                          validation_data=valid_generator,
                                          validation_steps=STEP_SIZE_VALID,
                                          epochs=40,
                                          callbacks=callback_list,
                                          verbose=1).history
    
    model.save('EfficientNetB0-'+fold+'sim2.h5')
    
    history = {'loss': history_warmup['loss'] + history_finetunning['loss'], 
               'val_loss': history_warmup['val_loss'] + history_finetunning['val_loss'], 
               'acc': history_warmup['accuracy'] + history_finetunning['accuracy'], 
               'val_acc': history_warmup['val_accuracy'] + history_finetunning['val_accuracy']}

    sns.set_style("whitegrid")
    fig, (ax1, ax2) = plt.subplots(2, 1, sharex='col', figsize=(20, 14))

    ax1.plot(history['loss'], label='Train loss')
    ax1.plot(history['val_loss'], label='Validation loss')
    ax1.legend(loc='best')
    ax1.set_title('Loss')
    plt.ylim([0,1])
    ax2.plot(history['acc'], label='Train Accuracy')
    ax2.plot(history['val_acc'], label='Validation Accuracy')
    ax2.legend(loc='best')
    ax2.set_title('Accuracy')
    ax2.set_ylim([0,1])
    plt.xlabel('Epochs')


    sns.despine()
    fig.savefig('acc-loss-'+fold)
    
    complete_datagen = ImageDataGenerator(rescale=1./255)
    complete_generator = complete_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/resized-2015-2019-blindness-detection-images/resized train 19",
        x_col="id_code",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)

    STEP_SIZE_COMPLETE = complete_generator.n//complete_generator.batch_size
    train_preds = model.predict_generator(complete_generator, steps=STEP_SIZE_COMPLETE)
    train_preds = [np.argmax(pred) for pred in train_preds]

    
    labels = ['0 - No DR', '1 - Mild', '2 - Moderate', '3 - Severe', '4 - Proliferative DR']
    cnf_matrix = confusion_matrix(test['diagnosis'].astype('int'), train_preds)
    cnf_matrix_norm = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    df_cm = pd.DataFrame(cnf_matrix_norm, index=labels, columns=labels)
    plt.figure(figsize=(16, 7))
    heatmap = sns.heatmap(df_cm, annot=True, fmt='.2f', cmap="Blues")
    heatmap = heatmap.get_figure()
    heatmap.savefig('heatmap-'+fold)
    
    print(fold+" - Train Cohen Kappa score: %.3f" % cohen_kappa_score(train_preds, test['diagnosis'].astype('int'), weights='quadratic'))

# %%
train_model(train_fold0, valid_fold0, 'FOLD0')
train_model(train_fold1, valid_fold1, 'FOLD1')
train_model(train_fold2, valid_fold2, 'FOLD2')
train_model(train_fold3, valid_fold3, 'FOLD3')
train_model(train_fold4, valid_fold4, 'FOLD4')
# Out:
# Found 2050 validated image filenames belonging to 5 classes.
# Found 513 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames.
# 2022-07-23 01:19:58.346097: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 01:19:58.516106: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 01:19:58.517975: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 01:19:58.520138: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-23 01:19:58.521618: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 01:19:58.522433: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 01:19:58.523190: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 01:20:00.973677: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 01:20:00.974672: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 01:20:00.975451: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-23 01:20:00.976109: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16711680/16705208 [==============================] - 0s 0us/step
# 16719872/16705208 [==============================] - 0s 0us/step
# 2022-07-23 01:20:04.284715: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/15
# 2022-07-23 01:20:11.223798: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 205/205 [==============================] - 221s 1s/step - loss: 1.3844 - accuracy: 0.4683 - val_loss: 1.3026 - val_accuracy: 0.5000
# Epoch 2/15
# 205/205 [==============================] - 195s 949ms/step - loss: 1.3283 - accuracy: 0.4844 - val_loss: 1.2975 - val_accuracy: 0.4980
# Epoch 3/15
# 205/205 [==============================] - 192s 938ms/step - loss: 1.3201 - accuracy: 0.4941 - val_loss: 1.2982 - val_accuracy: 0.4980
# Epoch 4/15
# 205/205 [==============================] - 194s 946ms/step - loss: 1.3172 - accuracy: 0.4927 - val_loss: 1.2952 - val_accuracy: 0.5000
# Epoch 5/15
# 205/205 [==============================] - 196s 957ms/step - loss: 1.3206 - accuracy: 0.4966 - val_loss: 1.2919 - val_accuracy: 0.5000
# Epoch 6/15
# 205/205 [==============================] - 197s 961ms/step - loss: 1.3211 - accuracy: 0.4961 - val_loss: 1.2951 - val_accuracy: 0.4980
# Epoch 7/15
# 205/205 [==============================] - 196s 955ms/step - loss: 1.3223 - accuracy: 0.4980 - val_loss: 1.2958 - val_accuracy: 0.4961
# Epoch 8/15
# 205/205 [==============================] - 197s 961ms/step - loss: 1.3134 - accuracy: 0.4966 - val_loss: 1.2937 - val_accuracy: 0.4980
# Epoch 9/15
# 205/205 [==============================] - 196s 959ms/step - loss: 1.3136 - accuracy: 0.4941 - val_loss: 1.2935 - val_accuracy: 0.4980
# Epoch 10/15
# 205/205 [==============================] - 198s 966ms/step - loss: 1.3083 - accuracy: 0.4966 - val_loss: 1.2994 - val_accuracy: 0.5000
40
# 205/205 [==============================] - 217s 1s/step - loss: 0.6798 - accuracy: 0.7472 - val_loss: 250.6606 - val_accuracy: 0.4804
# Epoch 3/40
# 205/205 [==============================] - 221s 1s/step - loss: 0.5876 - accuracy: 0.7692 - val_loss: 168.7574 - val_accuracy: 0.4667
# Epoch 4/40
# 205/205 [==============================] - 219s 1s/step - loss: 0.5460 - accuracy: 0.7913 - val_loss: 1.2570 - val_accuracy: 0.5000
# Epoch 5/40
# 205/205 [==============================] - 219s 1s/step - loss: 0.5162 - accuracy: 0.8070 - val_loss: 734.4351 - val_accuracy: 0.4745
# Epoch 6/40
# 205/205 [==============================] - 218s 1s/step - loss: 0.4628 - accuracy: 0.8123 - val_loss: 1793.6521 - val_accuracy: 0.4000
# Epoch 7/40
# 205/205 [==============================] - 223s 1s/step - loss: 0.4589 - accuracy: 0.8221 - val_loss: 331908.9062 - val_accuracy: 0.4804
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 8/40
# 205/205 [==============================] - 223s 1s/step - loss: 0.4219 - accuracy: 0.8378 - val_loss: 0.8879 - val_accuracy: 0.7098
# Epoch 9/40
# 205/205 [==============================] - 223s 1s/step - loss: 0.3899 - accuracy: 0.8584 - val_loss: 7491.3760 - val_accuracy: 0.1157
# Epoch 10/40
# 205/205 [==============================] - 220s 1s/step - loss: 0.3857 - accuracy: 0.8491 - val_loss: 0.8780 - val_accuracy: 0.6667
# Epoch 11/40
# 205/205 [==============================] - 224s 1s/step - loss: 0.3855 - accuracy: 0.8599 - val_loss: 12102.8340 - val_accuracy: 0.4647
# Epoch 12/40
# 205/205 [==============================] - 222s 1s/step - loss: 0.3597 - accuracy: 0.8633 - val_loss: 0.9129 - val_accuracy: 0.6529
# Epoch 13/40
# 205/205 [==============================] - 219s 1s/step - loss: 0.3567 - accuracy: 0.8618 - val_loss: 1.8413 - val_accuracy: 0.5843
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 14/40
# 205/205 [==============================] - 219s 1s/step - loss: 0.3242 - accuracy: 0.8721 - val_loss: 1.1289 - val_accuracy: 0.5549
# Epoch 15/40
# 205/205 [==============================] - 220s 1s/step - loss: 0.3079 - accuracy: 0.8868 - val_loss: 0.8190 - val_accuracy: 0.7314
# Epoch 16/40
# 205/205 [==============================] - 222s 1s/step - loss: 0.2923 - accuracy: 0.8888 - val_loss: 0.9514 - val_accuracy: 0.6549
# Epoch 17/40
# 205/205 [==============================] - 223s 1s/step - loss: 0.3010 - accuracy: 0.8858 - val_loss: 3800.5068 - val_accuracy: 0.5078
# Epoch 18/40
# 205/205 [==============================] - 227s 1s/step - loss: 0.2978 - accuracy: 0.8868 - val_loss: 0.9706 - val_accuracy: 0.6510
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 19/40
# 205/205 [==============================] - 218s 1s/step - loss: 0.2803 - accuracy: 0.8932 - val_loss: 0.8391 - val_accuracy: 0.7667
# Epoch 20/40
# 205/205 [==============================] - 215s 1s/step - loss: 0.2748 - accuracy: 0.8917 - val_loss: 2130.4756 - val_accuracy: 0.4706
# Restoring model weights from the end of the best epoch.
# Epoch 00020: early stopping
# Found 733 validated image filenames.
# FOLD3 - Train Cohen Kappa score: 0.659
# Found 2051 validated image filenames belonging to 5 classes.
# Found 512 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames.
# Epoch 1/15
# 205/205 [==============================] - 196s 915ms/step - loss: 1.3686 - accuracy: 0.4630 - val_loss: 1.3210 - val_accuracy: 0.4961
# Epoch 2/15
# 205/205 [==============================] - 187s 912ms/step - loss: 1.3406 - accuracy: 0.4787 - val_loss: 1.2968 - val_accuracy: 0.5000
# Epoch 3/15
# 205/205 [==============================] - 187s 908ms/step - loss: 1.3201 - accuracy: 0.4963 - val_loss: 1.3127 - val_accuracy: 0.4961
# Epoch 4/15
# 205/205 [==============================] - 184s 898ms/step - loss: 1.3192 - accuracy: 0.4939 - val_loss: 1.3032 - val_accuracy: 0.4961
# Epoch 5/15
# 205/205 [==============================] - 193s 941ms/step - loss: 1.3154 - accuracy: 0.4993 - val_loss: 1.3080 - val_accuracy: 0.4961
# Epoch 6/15
# 205/205 [==============================] - 183s 891ms/step - loss: 1.3179 - accuracy: 0.4953 - val_loss: 1.3157 - val_accuracy: 0.5000
# Epoch 7/15
# 205/205 [==============================] - 189s 922ms/step - loss: 1.3162 - accuracy: 0.4973 - val_loss: 1.3052 - val_accuracy: 0.4980
# Epoch 8/15
# 205/205 [==============================] - 183s 895ms/step - loss: 1.3130 - accuracy: 0.4973 - val_loss: 1.2987 - val_accuracy: 0.4980
# Epoch 9/15
# 205/205 [==============================] - 192s 939ms/step - loss: 1.3088 - accuracy: 0.4988 - val_loss: 1.2942 - val_accuracy: 0.4961
# Epoch 10/15
# 205/205 [==============================] - 185s 905ms/step - loss: 1.3200 - accuracy: 0.4953 - val_loss: 1.2991 - val_accuracy: 0.4980
# Epoch 11/15
# 205/205 [==============================] - 185s 901ms/step - loss: 1.3052 - accuracy: 0.4978 - val_loss: 1.2960 - val_accuracy: 0.4961
# Epoch 12/15
# 205/205 [==============================] - 188s 913ms/step - loss: 1.3122 - accuracy: 0.4998 - val_loss: 1.3148 - val_accuracy: 0.4961
# Epoch 13/15
# 205/205 [==============================] - 183s 893ms/step - loss: 1.3083 - accuracy: 0.4978 - val_loss: 1.2956 - val_accuracy: 0.4961
# Epoch 14/15
# 205/205 [==============================] - 183s 894ms/step - loss: 1.3163 - accuracy: 0.4983 - val_loss: 1.2959 - val_accuracy: 0.4961
# Epoch 15/15
# 205/205 [==============================] - 196s 955ms/step - loss: 1.3088 - accuracy: 0.4983 - val_loss: 1.2887 - val_accuracy: 0.5000
# Epoch 1/40
# 205/205 [==============================] - 219s 1s/step - loss: 0.9152 - accuracy: 0.6874 - val_loss: 1.4508 - val_accuracy: 0.4392
# Epoch 2/40
# 205/205 [==============================] - 215s 1s/step - loss: 0.6784 - accuracy: 0.7433 - val_loss: 1.2995 - val_accuracy: 0.6000
# Epoch 3/40
# 205/205 [==============================] - 217s 1s/step - loss: 0.6102 - accuracy: 0.7741 - val_loss: 1.3450 - val_accuracy: 0.5176
# Epoch 4/40
# 205/205 [==============================] - 216s 1s/step - loss: 0.5586 - accuracy: 0.7829 - val_loss: 13536.7725 - val_accuracy: 0.2863
# Epoch 5/40
# 205/205 [==============================] - 218s 1s/step - loss: 0.5048 - accuracy: 0.8074 - val_loss: 1.1533 - val_accuracy: 0.6157
# Epoch 6/40
# 205/205 [==============================] - 209s 1s/step - loss: 0.4765 - accuracy: 0.8207 - val_loss: 13.6330 - val_accuracy: 0.4529
# Epoch 7/40
# 205/205 [==============================] - 217s 1s/step - loss: 0.4779 - accuracy: 0.8158 - val_loss: 56.2627 - val_accuracy: 0.4373
# Epoch 8/40
# 205/205 [==============================] - 218s 1s/step - loss: 0.4534 - accuracy: 0.8305 - val_loss: 5862.5532 - val_accuracy: 0.4510
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 9/40
# 205/205 [==============================] - 216s 1s/step - loss: 0.3980 - accuracy: 0.8388 - val_loss: 1.2159 - val_accuracy: 0.5941
# Epoch 10/40
# 205/205 [==============================] - 206s 1s/step - loss: 0.3857 - accuracy: 0.8466 - val_loss: 10.5095 - val_accuracy: 0.5000
# Restoring model weights from the end of the best epoch.
# Epoch 00010: early stopping
# Found 733 validated image filenames.
# FOLD4 - Train Cohen Kappa score: 0.401
