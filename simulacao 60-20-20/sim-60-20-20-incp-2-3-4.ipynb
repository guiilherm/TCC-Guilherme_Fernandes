# %%
import os
import cv2
import random
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, cohen_kappa_score
import tensorflow as tf
import keras
from keras.models import Model
from keras import optimizers, applications
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import optimizers
from tensorflow.keras.applications import Xception, NASNetLarge, NASNetMobile, InceptionResNetV2,EfficientNetB0
from keras.layers import Dense, Dropout, GlobalAveragePooling2D, Input

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")

pd.options.display.max_colwidth = 100

# %%
data = pd.read_csv('../input/k-fold-new-data/5-fold.csv')
test = pd.read_csv('../input/k-fold-new-data/test.csv')

data['id_code'] = data['id_code'].apply(lambda x: x + '.jpg')
test['id_code'] = test['id_code'].apply(lambda x: x + '.jpg')

#fold 0
train_fold0 = data[data['fold_0'] == 'train'][['id_code','diagnosis']]
valid_fold0 = data[data['fold_0'] == 'validation'][['id_code','diagnosis']]

#fold 0
train_fold1 = data[data['fold_1'] == 'train'][['id_code','diagnosis']]
valid_fold1 = data[data['fold_1'] == 'validation'][['id_code','diagnosis']]

#fold 0
train_fold2 = data[data['fold_2'] == 'train'][['id_code','diagnosis']]
valid_fold2 = data[data['fold_2'] == 'validation'][['id_code','diagnosis']]

#fold 0
train_fold3 = data[data['fold_3'] == 'train'][['id_code','diagnosis']]
valid_fold3 = data[data['fold_3'] == 'validation'][['id_code','diagnosis']]

#fold 0
train_fold4 = data[data['fold_4'] == 'train'][['id_code','diagnosis']]
valid_fold4 = data[data['fold_4'] == 'validation'][['id_code','diagnosis']]

# %%
# Model parameters
BATCH_SIZE = 10
EPOCHS = 10
WARMUP_EPOCHS = 3
LEARNING_RATE = 1e-4
WARMUP_LEARNING_RATE = 1e-3
HEIGHT = 512
WIDTH = 512
CANAL = 3
N_CLASSES = train_fold0['diagnosis'].nunique()
ES_PATIENCE = 5
RLROP_PATIENCE = 3
DECAY_DROP = 0.5

metric_list = ["accuracy"]

# %%
def train_model(train_fold, valid_fold, fold):
    
    train_fold['diagnosis'] = train_fold['diagnosis'].astype(str)
    valid_fold['diagnosis'] = valid_fold['diagnosis'].astype(str)
    
    datagen=ImageDataGenerator(rescale=1./255, 
                           rotation_range=360,
                           horizontal_flip=True,
                           vertical_flip=True)

    train_generator=datagen.flow_from_dataframe(
                        dataframe=train_fold,
                        directory='../input/resized-2015-2019-blindness-detection-images/resized train 19',
                        x_col="id_code",
                        y_col="diagnosis",
                        class_mode="categorical",
                        batch_size=BATCH_SIZE,
                        target_size=(HEIGHT, WIDTH))

    valid_generator=datagen.flow_from_dataframe(
                        dataframe=valid_fold,
                        directory='../input/resized-2015-2019-blindness-detection-images/resized train 19',
                        x_col="id_code",
                        y_col="diagnosis",
                        class_mode="categorical",
                        batch_size=BATCH_SIZE,
                        target_size=(HEIGHT, WIDTH))

    test_generator=datagen.flow_from_dataframe(  
                       dataframe=test,
                       directory='../input/resized-2015-2019-blindness-detection-images/resized train 19',
                       x_col="id_code",
                       batch_size=1,
                       class_mode=None,
                       shuffle=False,
                       target_size=(HEIGHT, WIDTH))
    
    
    input_tensor = Input(shape=(HEIGHT, WIDTH, CANAL))
    base_model = InceptionResNetV2(weights='imagenet', 
                                       include_top=False,
                                       input_tensor=input_tensor)

    x = GlobalAveragePooling2D()(base_model.output)
    x = Dropout(0.5)(x)
    x = Dense(2048, activation='relu')(x)
    x = Dropout(0.5)(x)
    final_output = Dense(5, activation='softmax', name='final_output')(x)
    model = Model(input_tensor, final_output)
    
    for layer in model.layers:
        layer.trainable = False

    for i in range(-5, 0):
        model.layers[i].trainable = True

    metric_list = ["accuracy"]
    optimizer = tf.keras.optimizers.Adam(lr=WARMUP_LEARNING_RATE)
    model.compile(optimizer=optimizer, loss="categorical_crossentropy",  metrics=metric_list)
    
    STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
    STEP_SIZE_VALID = valid_generator.n//valid_generator.batch_size

    history_warmup = model.fit(train_generator,
                                     validation_data=valid_generator,
                                     steps_per_epoch=STEP_SIZE_TRAIN,
                                     validation_steps=STEP_SIZE_VALID,
                                     epochs=15,
                                     verbose=1).history
    
    for layer in model.layers:
        layer.trainable = True

    es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
    rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-6, verbose=1)

    callback_list = [es, rlrop]
    optimizer = tf.keras.optimizers.Adam(lr=LEARNING_RATE)
    model.compile(optimizer=optimizer, loss="categorical_crossentropy",  metrics=metric_list)
    
    history_finetunning = model.fit_generator(generator=train_generator,
                                          steps_per_epoch=STEP_SIZE_TRAIN,
                                          validation_data=valid_generator,
                                          validation_steps=STEP_SIZE_VALID,
                                          epochs=40,
                                          callbacks=callback_list,
                                          verbose=1).history
    
    model.save('InceptionResNetV2-'+fold+'sim1.h5')
    
    history = {'loss': history_warmup['loss'] + history_finetunning['loss'], 
               'val_loss': history_warmup['val_loss'] + history_finetunning['val_loss'], 
               'acc': history_warmup['accuracy'] + history_finetunning['accuracy'], 
               'val_acc': history_warmup['val_accuracy'] + history_finetunning['val_accuracy']}

    sns.set_style("whitegrid")
    fig, (ax1, ax2) = plt.subplots(2, 1, sharex='col', figsize=(20, 14))

    ax1.plot(history['loss'], label='Train loss')
    ax1.plot(history['val_loss'], label='Validation loss')
    ax1.legend(loc='best')
    ax1.set_title('Loss')
    plt.ylim([0,1])
    ax2.plot(history['acc'], label='Train Accuracy')
    ax2.plot(history['val_acc'], label='Validation Accuracy')
    ax2.legend(loc='best')
    ax2.set_title('Accuracy')
    ax2.set_ylim([0,1])
    plt.xlabel('Epochs')


    sns.despine()
    fig.savefig('acc-loss-'+fold)
    
    complete_datagen = ImageDataGenerator(rescale=1./255)
    complete_generator = complete_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/resized-2015-2019-blindness-detection-images/resized train 19",
        x_col="id_code",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)

    STEP_SIZE_COMPLETE = complete_generator.n//complete_generator.batch_size
    train_preds = model.predict_generator(complete_generator, steps=STEP_SIZE_COMPLETE)
    train_preds = [np.argmax(pred) for pred in train_preds]

    
    labels = ['0 - No DR', '1 - Mild', '2 - Moderate', '3 - Severe', '4 - Proliferative DR']
    cnf_matrix = confusion_matrix(test['diagnosis'].astype('int'), train_preds)
    cnf_matrix_norm = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    df_cm = pd.DataFrame(cnf_matrix_norm, index=labels, columns=labels)
    plt.figure(figsize=(16, 7))
    heatmap = sns.heatmap(df_cm, annot=True, fmt='.2f', cmap="Blues")
    heatmap = heatmap.get_figure()
    heatmap.savefig('heatmap-'+fold)
    
    print(fold+" - Train Cohen Kappa score: %.3f" % cohen_kappa_score(train_preds, test['diagnosis'].astype('int'), weights='quadratic'))

# %%
train_model(train_fold2, valid_fold2, 'FOLD2')
train_model(train_fold3, valid_fold3, 'FOLD3')
train_model(train_fold4, valid_fold4, 'FOLD4')
# Out:
# Found 1758 validated image filenames belonging to 5 classes.
# Found 439 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames.
# 2022-07-21 20:24:05.386342: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 20:24:05.501566: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 20:24:05.502374: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 20:24:05.506572: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-21 20:24:05.507833: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 20:24:05.508978: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 20:24:05.509743: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 20:24:07.530237: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 20:24:07.531034: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 20:24:07.531715: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 20:24:07.532343: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 4s 0us/step
# 219070464/219055592 [==============================] - 4s 0us/step
# 2022-07-21 20:24:17.968278: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/15
# 2022-07-21 20:24:28.277119: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 175/175 [==============================] - 188s 988ms/step - loss: 1.1596 - accuracy: 0.6201 - val_loss: 0.6752 - val_accuracy: 0.7419
# Epoch 2/15
# 175/175 [==============================] - 156s 892ms/step - loss: 0.8684 - accuracy: 0.6768 - val_loss: 0.6686 - val_accuracy: 0.7558
# Epoch 3/15
# 175/175 [==============================] - 153s 876ms/step - loss: 0.7749 - accuracy: 0.7025 - val_loss: 0.7186 - val_accuracy: 0.7279
# Epoch 4/15
# 175/175 [==============================] - 153s 876ms/step - loss: 0.7618 - accuracy: 0.7157 - val_loss: 0.7432 - val_accuracy: 0.6698
# Epoch 5/15
# 175/175 [==============================] - 150s 859ms/step - loss: 0.7293 - accuracy: 0.7145 - val_loss: 0.6538 - val_accuracy: 0.7558
# Epoch 6/15
# 175/175 [==============================] - 149s 853ms/step - loss: 0.7357 - accuracy: 0.7111 - val_loss: 0.6501 - val_accuracy: 0.7535
# Epoch 7/15
# 175/175 [==============================] - 148s 847ms/step - loss: 0.7377 - accuracy: 0.7265 - val_loss: 0.6199 - val_accuracy: 0.7512
# Epoch 8/15
# 175/175 [==============================] - 149s 847ms/step - loss: 0.7205 - accuracy: 0.7203 - val_loss: 0.6602 - val_accuracy: 0.7558
# Epoch 9/15
# 175/175 [==============================] - 150s 854ms/step - loss: 0.7103 - accuracy: 0.7317 - val_loss: 0.7404 - val_accuracy: 0.7349
# Epoch 10/15
# 175/175 [==============================] - 150s 851ms/step - loss: 0.7182 - accuracy: 0.7323 - val_loss: 0.6183 - val_accuracy: 0.7698
# Epoch 11/15
# 175/175 [==============================] - 149s 852ms/step - loss: 0.7227 - accuracy: 0.7271 - val_loss: 0.6412 - val_accuracy: 0.7605
# Epoch 12/15
# 175/175 [==============================] - 150s 854ms/step - loss: 0.6958 - accuracy: 0.7323 - val_loss: 0.6523 - val_accuracy: 0.7535
# Epoch 13/15
# 175/175 [==============================] - 149s 850ms/step - loss: 0.6994 - accuracy: 0.7346 - val_loss: 0.6105 - val_accuracy: 0.7721
# Epoch 14/15
# 175/175 [==============================] - 150s 856ms/step - loss: 0.7146 - accuracy: 0.7397 - val_loss: 0.6052 - val_accuracy: 0.7860
# Epoch 15/15
# 175/175 [==============================] - 150s 856ms/step - loss: 0.6864 - accuracy: 0.7248 - val_loss: 0.6323 - val_accuracy: 0.7535
# Epoch 1/40
# 175/175 [==============================] - 202s 1s/step - loss: 0.8567 - accuracy: 0.7042 - val_loss: 0.7896 - val_accuracy: 0.6977
# Epoch 2/40
# 175/175 [==============================] - 179s 1s/step - loss: 0.6419 - accuracy: 0.7477 - val_loss: 0.6761 - val_accuracy: 0.7465
# Epoch 3/40
# 175/175 [==============================] - 180s 1s/step - loss: 0.5481 - accuracy: 0.7775 - val_loss: 0.5428 - val_accuracy: 0.8093
# Epoch 4/40
# 175/175 [==============================] - 180s 1s/step - loss: 0.5101 - accuracy: 0.8038 - val_loss: 0.5757 - val_accuracy: 0.8116
# Epoch 5/40
# 175/175 [==============================] - 182s 1s/step - loss: 0.4656 - accuracy: 0.8192 - val_loss: 0.5240 - val_accuracy: 0.8116
# Epoch 6/40
# 175/175 [==============================] - 181s 1s/step - loss: 0.4496 - accuracy: 0.8215 - val_loss: 0.4890 - val_accuracy: 0.8093
# Epoch 7/40
# 175/175 [==============================] - 181s 1s/step - loss: 0.3951 - accuracy: 0.8404 - val_loss: 0.6738 - val_accuracy: 0.8000
# Epoch 8/40
# 175/175 [==============================] - 182s 1s/step - loss: 0.3911 - accuracy: 0.8410 - val_loss: 0.5309 - val_accuracy: 0.8163
# Epoch 9/40
# 175/175 [==============================] - 181s 1s/step - loss: 0.4008 - accuracy: 0.8455 - val_loss: 0.5596 - val_accuracy: 0.8140
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 10/40
# 175/175 [==============================] - 183s 1s/step - loss: 0.3372 - accuracy: 0.8713 - val_loss: 0.5206 - val_accuracy: 0.8209
# Epoch 11/40
# 175/175 [==============================] - 181s 1s/step - loss: 0.2993 - accuracy: 0.8884 - val_loss: 0.5176 - val_accuracy: 0.8395
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# Found 733 validated image filenames.
# FOLD2 - Train Cohen Kappa score: 0.885
# Found 1758 validated image filenames belonging to 5 classes.
# Found 439 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames.
# Epoch 1/15
# 175/175 [==============================] - 164s 883ms/step - loss: 1.1551 - accuracy: 0.6184 - val_loss: 0.7463 - val_accuracy: 0.7279
# Epoch 2/15
# 175/175 [==============================] - 151s 859ms/step - loss: 0.8333 - accuracy: 0.6808 - val_loss: 0.6886 - val_accuracy: 0.7395
# Epoch 3/15
# 175/175 [==============================] - 151s 861ms/step - loss: 0.7662 - accuracy: 0.7054 - val_loss: 0.6102 - val_accuracy: 0.7581
# Epoch 4/15
# 175/175 [==============================] - 151s 859ms/step - loss: 0.7854 - accuracy: 0.7128 - val_loss: 0.7347 - val_accuracy: 0.7349
# Epoch 5/15
# 175/175 [==============================] - 152s 867ms/step - loss: 0.7334 - accuracy: 0.7162 - val_loss: 0.6871 - val_accuracy: 0.7419
# Epoch 6/15
# 175/175 [==============================] - 151s 862ms/step - loss: 0.7521 - accuracy: 0.7231 - val_loss: 0.6384 - val_accuracy: 0.7535
# Epoch 7/15
# 175/175 [==============================] - 153s 870ms/step - loss: 0.7280 - accuracy: 0.7117 - val_loss: 0.6954 - val_accuracy: 0.7140
# Epoch 8/15
# 175/175 [==============================] - 151s 860ms/step - loss: 0.7259 - accuracy: 0.7243 - val_loss: 0.6101 - val_accuracy: 0.7535
# Epoch 9/15
# 175/175 [==============================] - 153s 873ms/step - loss: 0.7326 - accuracy: 0.7294 - val_loss: 0.6393 - val_accuracy: 0.7512
# Epoch 10/15
# 175/175 [==============================] - 152s 869ms/step - loss: 0.7017 - accuracy: 0.7271 - val_loss: 0.6644 - val_accuracy: 0.7442
# Epoch 11/15
# 175/175 [==============================] - 153s 870ms/step - loss: 0.7233 - accuracy: 0.7414 - val_loss: 0.6362 - val_accuracy: 0.7512
# Epoch 12/15
# 175/175 [==============================] - 154s 877ms/step - loss: 0.6929 - accuracy: 0.7363 - val_loss: 0.6098 - val_accuracy: 0.7605
# Epoch 13/15
# 175/175 [==============================] - 152s 869ms/step - loss: 0.7085 - accuracy: 0.7191 - val_loss: 0.6474 - val_accuracy: 0.7512
# Epoch 14/15
# 175/175 [==============================] - 154s 877ms/step - loss: 0.6953 - accuracy: 0.7351 - val_loss: 0.6230 - val_accuracy: 0.7535
# Epoch 15/15
# 175/175 [==============================] - 154s 877ms/step - loss: 0.6809 - accuracy: 0.7523 - val_loss: 0.6102 - val_accuracy: 0.7628
# Epoch 1/40
# 175/175 [==============================] - 202s 1s/step - loss: 0.8310 - accuracy: 0.7140 - val_loss: 0.6111 - val_accuracy: 0.7721
# Epoch 2/40
# 175/175 [==============================] - 184s 1s/step - loss: 0.6010 - accuracy: 0.7763 - val_loss: 0.5584 - val_accuracy: 0.7953
# Epoch 3/40
# 175/175 [==============================] - 184s 1s/step - loss: 0.5406 - accuracy: 0.7872 - val_loss: 0.5082 - val_accuracy: 0.7884
# Epoch 4/40
# 175/175 [==============================] - 186s 1s/step - loss: 0.5002 - accuracy: 0.7986 - val_loss: 0.5829 - val_accuracy: 0.7930
# Epoch 5/40
# 175/175 [==============================] - 185s 1s/step - loss: 0.4671 - accuracy: 0.8232 - val_loss: 0.5545 - val_accuracy: 0.7977
# Epoch 6/40
# 175/175 [==============================] - 184s 1s/step - loss: 0.4594 - accuracy: 0.8358 - val_loss: 0.5226 - val_accuracy: 0.8093
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 7/40
# 175/175 [==============================] - 186s 1s/step - loss: 0.3803 - accuracy: 0.8627 - val_loss: 0.5336 - val_accuracy: 0.8372
# Epoch 8/40
# 175/175 [==============================] - 184s 1s/step - loss: 0.3427 - accuracy: 0.8770 - val_loss: 0.4999 - val_accuracy: 0.8256
# Epoch 9/40
# 175/175 [==============================] - 185s 1s/step - loss: 0.3342 - accuracy: 0.8787 - val_loss: 0.4862 - val_accuracy: 0.8372
# Epoch 10/40
# 175/175 [==============================] - 186s 1s/step - loss: 0.3146 - accuracy: 0.8816 - val_loss: 0.5181 - val_accuracy: 0.8093
# Epoch 11/40
# 175/175 [==============================] - 187s 1s/step - loss: 0.3129 - accuracy: 0.8810 - val_loss: 0.6114 - val_accuracy: 0.8140
# Epoch 12/40
# 175/175 [==============================] - 185s 1s/step - loss: 0.2855 - accuracy: 0.9005 - val_loss: 0.5658 - val_accuracy: 0.8163
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 13/40
# 175/175 [==============================] - 184s 1s/step - loss: 0.2249 - accuracy: 0.9136 - val_loss: 0.5577 - val_accuracy: 0.8233
# Epoch 14/40
# 175/175 [==============================] - 187s 1s/step - loss: 0.2228 - accuracy: 0.9159 - val_loss: 0.6428 - val_accuracy: 0.7930
# Restoring model weights from the end of the best epoch.
# Epoch 00014: early stopping
# Found 733 validated image filenames.
# FOLD3 - Train Cohen Kappa score: 0.866
# Found 1758 validated image filenames belonging to 5 classes.
# Found 439 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames.
# Epoch 1/15
# 175/175 [==============================] - 169s 909ms/step - loss: 1.1396 - accuracy: 0.6138 - val_loss: 0.8388 - val_accuracy: 0.7047
# Epoch 2/15
# 175/175 [==============================] - 156s 891ms/step - loss: 0.8552 - accuracy: 0.6876 - val_loss: 0.6471 - val_accuracy: 0.7558
# Epoch 3/15
# 175/175 [==============================] - 156s 889ms/step - loss: 0.7779 - accuracy: 0.7105 - val_loss: 0.6235 - val_accuracy: 0.7605
# Epoch 4/15
# 175/175 [==============================] - 156s 890ms/step - loss: 0.7745 - accuracy: 0.7082 - val_loss: 0.6403 - val_accuracy: 0.7837
# Epoch 5/15
# 175/175 [==============================] - 156s 890ms/step - loss: 0.7652 - accuracy: 0.7082 - val_loss: 0.6145 - val_accuracy: 0.7814
# Epoch 6/15
# 175/175 [==============================] - 155s 883ms/step - loss: 0.7262 - accuracy: 0.7214 - val_loss: 0.6371 - val_accuracy: 0.7442
# Epoch 7/15
# 175/175 [==============================] - 157s 894ms/step - loss: 0.7062 - accuracy: 0.7277 - val_loss: 0.6439 - val_accuracy: 0.7395
# Epoch 8/15
# 175/175 [==============================] - 156s 892ms/step - loss: 0.7322 - accuracy: 0.7265 - val_loss: 0.6672 - val_accuracy: 0.7465
# Epoch 9/15
# 175/175 [==============================] - 157s 897ms/step - loss: 0.7044 - accuracy: 0.7294 - val_loss: 0.6379 - val_accuracy: 0.7558
# Epoch 10/15
# 175/175 [==============================] - 157s 897ms/step - loss: 0.7253 - accuracy: 0.7225 - val_loss: 0.6308 - val_accuracy: 0.7535
# Epoch 11/15
# 175/175 [==============================] - 159s 906ms/step - loss: 0.7134 - accuracy: 0.7317 - val_loss: 0.5967 - val_accuracy: 0.7651
# Epoch 12/15
# 175/175 [==============================] - 157s 898ms/step - loss: 0.7091 - accuracy: 0.7305 - val_loss: 0.6531 - val_accuracy: 0.7581
# Epoch 13/15
# 175/175 [==============================] - 158s 899ms/step - loss: 0.6991 - accuracy: 0.7294 - val_loss: 0.6235 - val_accuracy: 0.7721
# Epoch 14/15
# 175/175 [==============================] - 157s 894ms/step - loss: 0.7005 - accuracy: 0.7346 - val_loss: 0.6068 - val_accuracy: 0.7628
# Epoch 15/15
# 175/175 [==============================] - 157s 897ms/step - loss: 0.6962 - accuracy: 0.7386 - val_loss: 0.6014 - val_accuracy: 0.7721
# Epoch 1/40
# 175/175 [==============================] - 206s 1s/step - loss: 0.9583 - accuracy: 0.6905 - val_loss: 0.8761 - val_accuracy: 0.6698
# Epoch 2/40
# 175/175 [==============================] - 185s 1s/step - loss: 0.6392 - accuracy: 0.7597 - val_loss: 0.5623 - val_accuracy: 0.7791
# Epoch 3/40
# 175/175 [==============================] - 181s 1s/step - loss: 0.5742 - accuracy: 0.7849 - val_loss: 0.5115 - val_accuracy: 0.7953
# Epoch 4/40
# 175/175 [==============================] - 182s 1s/step - loss: 0.5296 - accuracy: 0.8038 - val_loss: 0.4814 - val_accuracy: 0.8070
# Epoch 5/40
# 175/175 [==============================] - 185s 1s/step - loss: 0.4723 - accuracy: 0.8175 - val_loss: 0.4240 - val_accuracy: 0.8419
# Epoch 6/40
# 175/175 [==============================] - 182s 1s/step - loss: 0.4706 - accuracy: 0.8124 - val_loss: 0.5492 - val_accuracy: 0.8233
# Epoch 7/40
# 175/175 [==============================] - 185s 1s/step - loss: 0.4581 - accuracy: 0.8204 - val_loss: 0.4188 - val_accuracy: 0.8279
# Epoch 8/40
# 175/175 [==============================] - 182s 1s/step - loss: 0.4178 - accuracy: 0.8404 - val_loss: 0.5102 - val_accuracy: 0.8116
# Epoch 9/40
# 175/175 [==============================] - 182s 1s/step - loss: 0.4489 - accuracy: 0.8289 - val_loss: 0.4388 - val_accuracy: 0.8512
# Epoch 10/40
# 175/175 [==============================] - 185s 1s/step - loss: 0.4036 - accuracy: 0.8501 - val_loss: 0.4142 - val_accuracy: 0.8279
# Epoch 11/40
# 175/175 [==============================] - 182s 1s/step - loss: 0.3663 - accuracy: 0.8587 - val_loss: 0.4732 - val_accuracy: 0.8233
# Epoch 12/40
# 175/175 [==============================] - 182s 1s/step - loss: 0.3753 - accuracy: 0.8610 - val_loss: 0.4208 - val_accuracy: 0.8349
# Epoch 13/40
# 175/175 [==============================] - 185s 1s/step - loss: 0.3494 - accuracy: 0.8667 - val_loss: 0.4690 - val_accuracy: 0.8233
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 14/40
# 175/175 [==============================] - 182s 1s/step - loss: 0.2770 - accuracy: 0.8942 - val_loss: 0.3931 - val_accuracy: 0.8605
# Epoch 15/40
# 175/175 [==============================] - 182s 1s/step - loss: 0.2531 - accuracy: 0.9050 - val_loss: 0.4549 - val_accuracy: 0.8186
# Epoch 16/40
# 175/175 [==============================] - 186s 1s/step - loss: 0.2188 - accuracy: 0.9148 - val_loss: 0.5016 - val_accuracy: 0.8302
# Epoch 17/40
# 175/175 [==============================] - 182s 1s/step - loss: 0.2221 - accuracy: 0.9176 - val_loss: 0.3967 - val_accuracy: 0.8488
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 18/40
# 175/175 [==============================] - 183s 1s/step - loss: 0.1811 - accuracy: 0.9314 - val_loss: 0.4737 - val_accuracy: 0.8628
# Epoch 19/40
# 175/175 [==============================] - 186s 1s/step - loss: 0.1515 - accuracy: 0.9422 - val_loss: 0.4753 - val_accuracy: 0.8488
# Restoring model weights from the end of the best epoch.
# Epoch 00019: early stopping
# Found 733 validated image filenames.
# FOLD4 - Train Cohen Kappa score: 0.902
