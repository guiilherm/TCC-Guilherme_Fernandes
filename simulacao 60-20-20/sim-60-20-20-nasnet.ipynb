# %%
import os
import cv2
import random
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, cohen_kappa_score
import tensorflow as tf
import keras
from keras.models import Model
from keras import optimizers, applications
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import optimizers
from tensorflow.keras.applications import Xception, NASNetLarge, NASNetMobile, InceptionResNetV2,EfficientNetB0
from keras.layers import Dense, Dropout, GlobalAveragePooling2D, Input

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")

pd.options.display.max_colwidth = 100

# %%
data = pd.read_csv('../input/k-fold-new-data/5-fold.csv')
test = pd.read_csv('../input/k-fold-new-data/test.csv')

data['id_code'] = data['id_code'].apply(lambda x: x + '.jpg')
test['id_code'] = test['id_code'].apply(lambda x: x + '.jpg')

#fold 0
train_fold0 = data[data['fold_0'] == 'train'][['id_code','diagnosis']]
valid_fold0 = data[data['fold_0'] == 'validation'][['id_code','diagnosis']]

#fold 0
train_fold1 = data[data['fold_1'] == 'train'][['id_code','diagnosis']]
valid_fold1 = data[data['fold_1'] == 'validation'][['id_code','diagnosis']]

#fold 0
train_fold2 = data[data['fold_2'] == 'train'][['id_code','diagnosis']]
valid_fold2 = data[data['fold_2'] == 'validation'][['id_code','diagnosis']]

#fold 0
train_fold3 = data[data['fold_3'] == 'train'][['id_code','diagnosis']]
valid_fold3 = data[data['fold_3'] == 'validation'][['id_code','diagnosis']]

#fold 0
train_fold4 = data[data['fold_4'] == 'train'][['id_code','diagnosis']]
valid_fold4 = data[data['fold_4'] == 'validation'][['id_code','diagnosis']]

# %%
# Model parameters
BATCH_SIZE = 10
EPOCHS = 10
WARMUP_EPOCHS = 3
LEARNING_RATE = 1e-4
WARMUP_LEARNING_RATE = 1e-3
HEIGHT = 512
WIDTH = 512
CANAL = 3
N_CLASSES = train_fold0['diagnosis'].nunique()
ES_PATIENCE = 5
RLROP_PATIENCE = 3
DECAY_DROP = 0.5

metric_list = ["accuracy"]

# %%
def train_model(train_fold, valid_fold, fold):
    
    train_fold['diagnosis'] = train_fold['diagnosis'].astype(str)
    valid_fold['diagnosis'] = valid_fold['diagnosis'].astype(str)
    
    datagen=ImageDataGenerator(rescale=1./255, 
                           rotation_range=360,
                           horizontal_flip=True,
                           vertical_flip=True)

    train_generator=datagen.flow_from_dataframe(
                        dataframe=train_fold,
                        directory='../input/resized-2015-2019-blindness-detection-images/resized train 19',
                        x_col="id_code",
                        y_col="diagnosis",
                        class_mode="categorical",
                        batch_size=BATCH_SIZE,
                        target_size=(HEIGHT, WIDTH))

    valid_generator=datagen.flow_from_dataframe(
                        dataframe=valid_fold,
                        directory='../input/resized-2015-2019-blindness-detection-images/resized train 19',
                        x_col="id_code",
                        y_col="diagnosis",
                        class_mode="categorical",
                        batch_size=BATCH_SIZE,
                        target_size=(HEIGHT, WIDTH))

    test_generator=datagen.flow_from_dataframe(  
                       dataframe=test,
                       directory='../input/resized-2015-2019-blindness-detection-images/resized train 19',
                       x_col="id_code",
                       batch_size=1,
                       class_mode=None,
                       shuffle=False,
                       target_size=(HEIGHT, WIDTH))
    
    
    input_tensor = Input(shape=(HEIGHT, WIDTH, CANAL))
    base_model = NASNetMobile(weights='imagenet', 
                                       include_top=False,
                                       input_tensor=input_tensor)

    x = GlobalAveragePooling2D()(base_model.output)
    x = Dropout(0.5)(x)
    x = Dense(2048, activation='relu')(x)
    x = Dropout(0.5)(x)
    final_output = Dense(5, activation='softmax', name='final_output')(x)
    model = Model(input_tensor, final_output)
    
    for layer in model.layers:
        layer.trainable = False

    for i in range(-5, 0):
        model.layers[i].trainable = True

    metric_list = ["accuracy"]
    optimizer = tf.keras.optimizers.Adam(lr=WARMUP_LEARNING_RATE)
    model.compile(optimizer=optimizer, loss="categorical_crossentropy",  metrics=metric_list)
    
    STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
    STEP_SIZE_VALID = valid_generator.n//valid_generator.batch_size

    history_warmup = model.fit(train_generator,
                                     validation_data=valid_generator,
                                     steps_per_epoch=STEP_SIZE_TRAIN,
                                     validation_steps=STEP_SIZE_VALID,
                                     epochs=15,
                                     verbose=1).history
    
    for layer in model.layers:
        layer.trainable = True

    es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
    rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-6, verbose=1)

    callback_list = [es, rlrop]
    optimizer = tf.keras.optimizers.Adam(lr=LEARNING_RATE)
    model.compile(optimizer=optimizer, loss="categorical_crossentropy",  metrics=metric_list)
    
    history_finetunning = model.fit_generator(generator=train_generator,
                                          steps_per_epoch=STEP_SIZE_TRAIN,
                                          validation_data=valid_generator,
                                          validation_steps=STEP_SIZE_VALID,
                                          epochs=40,
                                          callbacks=callback_list,
                                          verbose=1).history
    
    model.save('NASNetMobile-'+fold+'sim1.h5')
    
    history = {'loss': history_warmup['loss'] + history_finetunning['loss'], 
               'val_loss': history_warmup['val_loss'] + history_finetunning['val_loss'], 
               'acc': history_warmup['accuracy'] + history_finetunning['accuracy'], 
               'val_acc': history_warmup['val_accuracy'] + history_finetunning['val_accuracy']}

    sns.set_style("whitegrid")
    fig, (ax1, ax2) = plt.subplots(2, 1, sharex='col', figsize=(20, 14))

    ax1.plot(history['loss'], label='Train loss')
    ax1.plot(history['val_loss'], label='Validation loss')
    ax1.legend(loc='best')
    ax1.set_title('Loss')
    plt.ylim([0,1])
    ax2.plot(history['acc'], label='Train Accuracy')
    ax2.plot(history['val_acc'], label='Validation Accuracy')
    ax2.legend(loc='best')
    ax2.set_title('Accuracy')
    ax2.set_ylim([0,1])
    plt.xlabel('Epochs')


    sns.despine()
    fig.savefig('acc-loss-'+fold)
    
    complete_datagen = ImageDataGenerator(rescale=1./255)
    complete_generator = complete_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/resized-2015-2019-blindness-detection-images/resized train 19",
        x_col="id_code",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)

    STEP_SIZE_COMPLETE = complete_generator.n//complete_generator.batch_size
    train_preds = model.predict_generator(complete_generator, steps=STEP_SIZE_COMPLETE)
    train_preds = [np.argmax(pred) for pred in train_preds]

    
    labels = ['0 - No DR', '1 - Mild', '2 - Moderate', '3 - Severe', '4 - Proliferative DR']
    cnf_matrix = confusion_matrix(test['diagnosis'].astype('int'), train_preds)
    cnf_matrix_norm = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    df_cm = pd.DataFrame(cnf_matrix_norm, index=labels, columns=labels)
    plt.figure(figsize=(16, 7))
    heatmap = sns.heatmap(df_cm, annot=True, fmt='.2f', cmap="Blues")
    heatmap = heatmap.get_figure()
    heatmap.savefig('heatmap-'+fold)
    
    print(fold+" - Train Cohen Kappa score: %.3f" % cohen_kappa_score(train_preds, test['diagnosis'].astype('int'), weights='quadratic'))

# %%
train_model(train_fold0, valid_fold0, 'FOLD0')
train_model(train_fold1, valid_fold1, 'FOLD1')
train_model(train_fold2, valid_fold2, 'FOLD2')
train_model(train_fold3, valid_fold3, 'FOLD3')
train_model(train_fold4, valid_fold4, 'FOLD4')
# Out:
# Found 1757 validated image filenames belonging to 5 classes.
# Found 440 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames.
# 2022-07-21 20:34:52.509208: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 20:34:52.682841: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 20:34:52.684040: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 20:34:52.686774: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-21 20:34:52.688087: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 20:34:52.689440: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 20:34:52.690803: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 20:34:55.405415: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 20:34:55.406597: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 20:34:55.407484: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 20:34:55.408313: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19996672/19993432 [==============================] - 1s 0us/step
# 20004864/19993432 [==============================] - 1s 0us/step
# 2022-07-21 20:35:04.975602: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/15
# 2022-07-21 20:35:21.020612: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 175/175 [==============================] - 198s 1s/step - loss: 1.1392 - accuracy: 0.6039 - val_loss: 0.8587 - val_accuracy: 0.6727
# Epoch 2/15
# 175/175 [==============================] - 151s 866ms/step - loss: 0.9518 - accuracy: 0.6485 - val_loss: 0.8289 - val_accuracy: 0.7273
# Epoch 3/15
# 175/175 [==============================] - 152s 870ms/step - loss: 0.8662 - accuracy: 0.6795 - val_loss: 0.8832 - val_accuracy: 0.6977
# Epoch 4/15
# 175/175 [==============================] - 153s 874ms/step - loss: 0.8209 - accuracy: 0.6983 - val_loss: 0.8505 - val_accuracy: 0.6614
# Epoch 5/15
# 175/175 [==============================] - 152s 869ms/step - loss: 0.8376 - accuracy: 0.7001 - val_loss: 0.7849 - val_accuracy: 0.7159
# Epoch 6/15
# 175/175 [==============================] - 153s 872ms/step - loss: 0.8067 - accuracy: 0.7041 - val_loss: 0.7237 - val_accuracy: 0.7273
# Epoch 7/15
# 175/175 [==============================] - 153s 871ms/step - loss: 0.7887 - accuracy: 0.7006 - val_loss: 0.7166 - val_accuracy: 0.7409
# Epoch 8/15
# 175/175 [==============================] - 153s 873ms/step - loss: 0.8061 - accuracy: 0.7138 - val_loss: 0.7207 - val_accuracy: 0.7386
# Epoch 9/15
# 175/175 [==============================] - 154s 877ms/step - loss: 0.7824 - accuracy: 0.7178 - val_loss: 0.6893 - val_accuracy: 0.7341
# Epoch 10/15
# 175/175 [==============================] - 154s 880ms/step - loss: 0.7670 - accuracy: 0.7184 - val_loss: 0.7444 - val_accuracy: 0.7000
# Epoch 11/15
# 175/175 [==============================] - 154s 880ms/step - loss: 0.7693 - accuracy: 0.7167 - val_loss: 0.7640 - val_accuracy: 0.7114
# Epoch 12/15
# 175/175 [==============================] - 155s 881ms/step - loss: 0.7629 - accuracy: 0.7207 - val_loss: 0.6722 - val_accuracy: 0.7386
# Epoch 13/15
# 175/175 [==============================] - 156s 888ms/step - loss: 0.7734 - accuracy: 0.7104 - val_loss: 0.6981 - val_accuracy: 0.7523
# Epoch 14/15
# 175/175 [==============================] - 156s 890ms/step - loss: 0.7657 - accuracy: 0.7230 - val_loss: 0.6892 - val_accuracy: 0.7477
# Epoch 15/15
# 175/175 [==============================] - 155s 885ms/step - loss: 0.7313 - accuracy: 0.7224 - val_loss: 0.7240 - val_accuracy: 0.7409
# Epoch 1/40
# 175/175 [==============================] - 247s 1s/step - loss: 1.1590 - accuracy: 0.6651 - val_loss: 0.7253 - val_accuracy: 0.7386
# Epoch 2/40
# 175/175 [==============================] - 217s 1s/step - loss: 0.6998 - accuracy: 0.7287 - val_loss: 0.6540 - val_accuracy: 0.7659
# Epoch 3/40
# 175/175 [==============================] - 212s 1s/step - loss: 0.6408 - accuracy: 0.7579 - val_loss: 0.8884 - val_accuracy: 0.7000
# Epoch 4/40
# 175/175 [==============================] - 211s 1s/step - loss: 0.5718 - accuracy: 0.7808 - val_loss: 0.7868 - val_accuracy: 0.7318
# Epoch 5/40
# 175/175 [==============================] - 209s 1s/step - loss: 0.5159 - accuracy: 0.7911 - val_loss: 1.0223 - val_accuracy: 0.7114
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 6/40
# 175/175 [==============================] - 212s 1s/step - loss: 0.4794 - accuracy: 0.8111 - val_loss: 0.8262 - val_accuracy: 0.7318
# Epoch 7/40
# 175/175 [==============================] - 214s 1s/step - loss: 0.4825 - accuracy: 0.8168 - val_loss: 0.6610 - val_accuracy: 0.7682
# Restoring model weights from the end of the best epoch.
# Epoch 00007: early stopping
# Found 733 validated image filenames.
# FOLD0 - Train Cohen Kappa score: 0.751
# Found 1757 validated image filenames belonging to 5 classes.
# Found 440 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames.
# Epoch 1/15
# 175/175 [==============================] - 176s 920ms/step - loss: 1.1860 - accuracy: 0.5936 - val_loss: 0.8784 - val_accuracy: 0.7136
# Epoch 2/15
# 175/175 [==============================] - 156s 892ms/step - loss: 0.9359 - accuracy: 0.6674 - val_loss: 0.8171 - val_accuracy: 0.6523
# Epoch 3/15
# 175/175 [==============================] - 157s 892ms/step - loss: 0.8662 - accuracy: 0.6829 - val_loss: 0.7143 - val_accuracy: 0.7409
# Epoch 4/15
# 175/175 [==============================] - 158s 901ms/step - loss: 0.8923 - accuracy: 0.6772 - val_loss: 0.7029 - val_accuracy: 0.7114
# Epoch 5/15
# 175/175 [==============================] - 159s 906ms/step - loss: 0.8258 - accuracy: 0.6972 - val_loss: 0.7242 - val_accuracy: 0.7318
# Epoch 6/15
# 175/175 [==============================] - 156s 888ms/step - loss: 0.8057 - accuracy: 0.6995 - val_loss: 0.7271 - val_accuracy: 0.7295
# Epoch 7/15
# 175/175 [==============================] - 154s 876ms/step - loss: 0.7912 - accuracy: 0.7069 - val_loss: 0.6992 - val_accuracy: 0.7295
# Epoch 8/15
# 175/175 [==============================] - 156s 883ms/step - loss: 0.8190 - accuracy: 0.6978 - val_loss: 0.7191 - val_accuracy: 0.7386
# Epoch 9/15
# 175/175 [==============================] - 156s 889ms/step - loss: 0.8116 - accuracy: 0.7115 - val_loss: 0.7275 - val_accuracy: 0.6864
# Epoch 10/15
# 175/175 [==============================] - 157s 898ms/step - loss: 0.7807 - accuracy: 0.7172 - val_loss: 0.6818 - val_accuracy: 0.7273
# Epoch 11/15
# 175/175 [==============================] - 156s 888ms/step - loss: 0.7765 - accuracy: 0.7172 - val_loss: 0.6553 - val_accuracy: 0.7432
# Epoch 12/15
# 175/175 [==============================] - 157s 895ms/step - loss: 0.7623 - accuracy: 0.7195 - val_loss: 0.7048 - val_accuracy: 0.7409
# Epoch 13/15
# 175/175 [==============================] - 159s 906ms/step - loss: 0.7771 - accuracy: 0.7121 - val_loss: 0.6829 - val_accuracy: 0.7318
# Epoch 14/15
# 175/175 [==============================] - 158s 904ms/step - loss: 0.7673 - accuracy: 0.7184 - val_loss: 0.6780 - val_accuracy: 0.7295
# Epoch 15/15
# 175/175 [==============================] - 158s 901ms/step - loss: 0.7698 - accuracy: 0.7195 - val_loss: 0.6577 - val_accuracy: 0.7364
# Epoch 1/40
# 175/175 [==============================] - 251s 1s/step - loss: 1.1708 - accuracy: 0.6686 - val_loss: 0.7657 - val_accuracy: 0.7205
# Epoch 2/40
# 175/175 [==============================] - 218s 1s/step - loss: 0.6763 - accuracy: 0.7310 - val_loss: 0.6815 - val_accuracy: 0.7432
# Epoch 3/40
# 175/175 [==============================] - 220s 1s/step - loss: 0.6355 - accuracy: 0.7487 - val_loss: 0.6957 - val_accuracy: 0.7386
# Epoch 4/40
# 175/175 [==============================] - 221s 1s/step - loss: 0.5868 - accuracy: 0.7865 - val_loss: 0.9591 - val_accuracy: 0.6727
# Epoch 5/40
# 175/175 [==============================] - 220s 1s/step - loss: 0.5479 - accuracy: 0.7871 - val_loss: 0.6777 - val_accuracy: 0.7318
# Epoch 6/40
# 175/175 [==============================] - 226s 1s/step - loss: 0.5221 - accuracy: 0.8042 - val_loss: 0.7396 - val_accuracy: 0.7364
# Epoch 7/40
# 175/175 [==============================] - 220s 1s/step - loss: 0.4684 - accuracy: 0.8197 - val_loss: 0.9862 - val_accuracy: 0.7205
# Epoch 8/40
# 175/175 [==============================] - 228s 1s/step - loss: 0.4604 - accuracy: 0.8243 - val_loss: 0.9268 - val_accuracy: 0.7500
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 9/40
# 175/175 [==============================] - 234s 1s/step - loss: 0.4133 - accuracy: 0.8329 - val_loss: 0.8242 - val_accuracy: 0.7386
# Epoch 10/40
# 175/175 [==============================] - 234s 1s/step - loss: 0.4027 - accuracy: 0.8489 - val_loss: 0.9492 - val_accuracy: 0.7432
# Restoring model weights from the end of the best epoch.
# Epoch 00010: early stopping
# Found 733 validated image filenames.
# FOLD1 - Train Cohen Kappa score: 0.799
# Found 1758 validated image filenames belonging to 5 classes.
# Found 439 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames.
# Epoch 1/15
# 175/175 [==============================] - 211s 1s/step - loss: 1.1695 - accuracy: 0.5990 - val_loss: 0.8375 - val_accuracy: 0.6209
# Epoch 2/15
# 175/175 [==============================] - 186s 1s/step - loss: 0.9381 - accuracy: 0.6516 - val_loss: 0.7137 - val_accuracy: 0.7233
# Epoch 3/15
# 175/175 [==============================] - 181s 1s/step - loss: 0.9188 - accuracy: 0.6636 - val_loss: 0.7786 - val_accuracy: 0.7326
# Epoch 4/15
# 175/175 [==============================] - 181s 1s/step - loss: 0.8576 - accuracy: 0.6842 - val_loss: 0.7345 - val_accuracy: 0.7372
# Epoch 5/15
# 175/175 [==============================] - 178s 1s/step - loss: 0.8519 - accuracy: 0.6831 - val_loss: 0.7356 - val_accuracy: 0.7326
# Epoch 6/15
# 175/175 [==============================] - 179s 1s/step - loss: 0.8328 - accuracy: 0.6962 - val_loss: 0.7322 - val_accuracy: 0.7233
# Epoch 7/15
# 175/175 [==============================] - 183s 1s/step - loss: 0.7860 - accuracy: 0.7042 - val_loss: 0.7214 - val_accuracy: 0.7442
# Epoch 8/15
# 175/175 [==============================] - 182s 1s/step - loss: 0.7976 - accuracy: 0.6960 - val_loss: 0.7319 - val_accuracy: 0.7256
# Epoch 9/15
# 175/175 [==============================] - 180s 1s/step - loss: 0.7852 - accuracy: 0.7082 - val_loss: 0.7059 - val_accuracy: 0.7465
# Epoch 10/15
# 175/175 [==============================] - 192s 1s/step - loss: 0.7885 - accuracy: 0.7077 - val_loss: 0.6846 - val_accuracy: 0.7535
# Epoch 11/15
# 175/175 [==============================] - 179s 1s/step - loss: 0.7702 - accuracy: 0.7082 - val_loss: 0.6686 - val_accuracy: 0.7791
# Epoch 12/15
# 175/175 [==============================] - 182s 1s/step - loss: 0.7616 - accuracy: 0.7151 - val_loss: 0.7148 - val_accuracy: 0.7465
# Epoch 13/15
# 175/175 [==============================] - 181s 1s/step - loss: 0.7650 - accuracy: 0.7082 - val_loss: 0.6931 - val_accuracy: 0.7326
# Epoch 14/15
# 175/175 [==============================] - 181s 1s/step - loss: 0.7554 - accuracy: 0.7088 - val_loss: 0.7050 - val_accuracy: 0.7372
# Epoch 15/15
# 175/175 [==============================] - 183s 1s/step - loss: 0.7808 - accuracy: 0.7128 - val_loss: 0.6968 - val_accuracy: 0.7070
# Epoch 1/40
# 175/175 [==============================] - 275s 1s/step - loss: 1.1501 - accuracy: 0.6562 - val_loss: 0.7063 - val_accuracy: 0.7419
# Epoch 2/40
# 175/175 [==============================] - 239s 1s/step - loss: 0.7007 - accuracy: 0.7305 - val_loss: 0.7965 - val_accuracy: 0.7488
# Epoch 3/40
# 175/175 [==============================] - 238s 1s/step - loss: 0.6271 - accuracy: 0.7637 - val_loss: 0.7117 - val_accuracy: 0.7698
# Epoch 4/40
# 175/175 [==============================] - 239s 1s/step - loss: 0.5585 - accuracy: 0.7797 - val_loss: 0.7680 - val_accuracy: 0.7279
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 5/40
# 175/175 [==============================] - 239s 1s/step - loss: 0.5196 - accuracy: 0.7923 - val_loss: 0.8415 - val_accuracy: 0.7302
# Epoch 6/40
# 175/175 [==============================] - 240s 1s/step - loss: 0.4730 - accuracy: 0.8118 - val_loss: 0.8122 - val_accuracy: 0.7395
# Restoring model weights from the end of the best epoch.
# Epoch 00006: early stopping
# Found 733 validated image filenames.
# FOLD2 - Train Cohen Kappa score: 0.689
# Found 1758 validated image filenames belonging to 5 classes.
# Found 439 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames.
# Epoch 1/15
# 175/175 [==============================] - 205s 1s/step - loss: 1.1642 - accuracy: 0.6001 - val_loss: 0.8072 - val_accuracy: 0.6977
# Epoch 2/15
# 175/175 [==============================] - 182s 1s/step - loss: 0.9620 - accuracy: 0.6579 - val_loss: 0.7958 - val_accuracy: 0.6326
# Epoch 3/15
# 175/175 [==============================] - 186s 1s/step - loss: 0.8853 - accuracy: 0.6779 - val_loss: 0.7021 - val_accuracy: 0.7372
# Epoch 4/15
# 175/175 [==============================] - 180s 1s/step - loss: 0.8489 - accuracy: 0.6905 - val_loss: 0.7094 - val_accuracy: 0.7302
# Epoch 5/15
# 175/175 [==============================] - 180s 1s/step - loss: 0.8513 - accuracy: 0.6905 - val_loss: 0.7028 - val_accuracy: 0.7256
# Epoch 6/15
# 175/175 [==============================] - 186s 1s/step - loss: 0.8170 - accuracy: 0.7014 - val_loss: 0.6763 - val_accuracy: 0.7326
# Epoch 7/15
# 175/175 [==============================] - 181s 1s/step - loss: 0.8013 - accuracy: 0.6974 - val_loss: 0.6812 - val_accuracy: 0.7419
# Epoch 8/15
# 175/175 [==============================] - 181s 1s/step - loss: 0.7963 - accuracy: 0.7059 - val_loss: 0.7085 - val_accuracy: 0.7512
# Epoch 9/15
# 175/175 [==============================] - 188s 1s/step - loss: 0.8001 - accuracy: 0.7019 - val_loss: 0.6828 - val_accuracy: 0.7721
# Epoch 10/15
# 175/175 [==============================] - 181s 1s/step - loss: 0.7857 - accuracy: 0.7145 - val_loss: 0.7011 - val_accuracy: 0.7186
# Epoch 11/15
# 175/175 [==============================] - 187s 1s/step - loss: 0.7930 - accuracy: 0.7019 - val_loss: 0.6869 - val_accuracy: 0.7349
# Epoch 12/15
# 175/175 [==============================] - 185s 1s/step - loss: 0.7620 - accuracy: 0.7203 - val_loss: 0.6666 - val_accuracy: 0.7488
# Epoch 13/15
# 175/175 [==============================] - 189s 1s/step - loss: 0.7693 - accuracy: 0.7117 - val_loss: 0.6783 - val_accuracy: 0.7395
# Epoch 14/15
# 175/175 [==============================] - 182s 1s/step - loss: 0.7567 - accuracy: 0.7191 - val_loss: 0.6545 - val_accuracy: 0.7628
# Epoch 15/15
# 175/175 [==============================] - 185s 1s/step - loss: 0.7632 - accuracy: 0.7174 - val_loss: 0.6521 - val_accuracy: 0.7488
# Epoch 1/40
# 175/175 [==============================] - 276s 1s/step - loss: 1.0343 - accuracy: 0.6779 - val_loss: 0.6635 - val_accuracy: 0.7512
# Epoch 2/40
# 175/175 [==============================] - 244s 1s/step - loss: 0.6930 - accuracy: 0.7466 - val_loss: 0.6624 - val_accuracy: 0.7535
# Epoch 3/40
# 175/175 [==============================] - 246s 1s/step - loss: 0.6831 - accuracy: 0.7569 - val_loss: 0.6752 - val_accuracy: 0.7442
# Epoch 4/40
# 175/175 [==============================] - 244s 1s/step - loss: 0.5721 - accuracy: 0.7855 - val_loss: 0.6900 - val_accuracy: 0.7605
# Epoch 5/40
# 175/175 [==============================] - 242s 1s/step - loss: 0.5306 - accuracy: 0.7998 - val_loss: 0.8484 - val_accuracy: 0.7070
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 6/40
# 175/175 [==============================] - 240s 1s/step - loss: 0.4669 - accuracy: 0.8221 - val_loss: 0.7496 - val_accuracy: 0.7535
# Epoch 7/40
# 175/175 [==============================] - 238s 1s/step - loss: 0.4890 - accuracy: 0.8124 - val_loss: 0.8326 - val_accuracy: 0.7558
# Restoring model weights from the end of the best epoch.
# Epoch 00007: early stopping
# Found 733 validated image filenames.
# FOLD3 - Train Cohen Kappa score: 0.755
# Found 1758 validated image filenames belonging to 5 classes.
# Found 439 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames.
# Epoch 1/15
# 175/175 [==============================] - 208s 1s/step - loss: 1.1685 - accuracy: 0.6121 - val_loss: 0.8090 - val_accuracy: 0.7419
# Epoch 2/15
# 175/175 [==============================] - 166s 947ms/step - loss: 0.9602 - accuracy: 0.6522 - val_loss: 0.7439 - val_accuracy: 0.7349
# Epoch 3/15
# 175/175 [==============================] - 159s 905ms/step - loss: 0.8880 - accuracy: 0.6665 - val_loss: 0.7336 - val_accuracy: 0.7512
# Epoch 4/15
# 175/175 [==============================] - 158s 906ms/step - loss: 0.8507 - accuracy: 0.6836 - val_loss: 0.6879 - val_accuracy: 0.7395
# Epoch 5/15
# 175/175 [==============================] - 158s 905ms/step - loss: 0.8430 - accuracy: 0.6916 - val_loss: 0.6830 - val_accuracy: 0.7535
# Epoch 6/15
# 175/175 [==============================] - 158s 896ms/step - loss: 0.8098 - accuracy: 0.7059 - val_loss: 0.6888 - val_accuracy: 0.7535
# Epoch 7/15
# 175/175 [==============================] - 157s 900ms/step - loss: 0.8244 - accuracy: 0.6876 - val_loss: 0.7115 - val_accuracy: 0.7349
# Epoch 8/15
# 175/175 [==============================] - 157s 896ms/step - loss: 0.7787 - accuracy: 0.7077 - val_loss: 0.6287 - val_accuracy: 0.7581
# Epoch 9/15
# 175/175 [==============================] - 156s 895ms/step - loss: 0.8063 - accuracy: 0.7008 - val_loss: 0.7441 - val_accuracy: 0.7442
# Epoch 10/15
# 175/175 [==============================] - 157s 901ms/step - loss: 0.7819 - accuracy: 0.7185 - val_loss: 0.6437 - val_accuracy: 0.7651
# Epoch 11/15
# 175/175 [==============================] - 157s 894ms/step - loss: 0.7797 - accuracy: 0.7117 - val_loss: 0.6777 - val_accuracy: 0.7628
# Epoch 12/15
# 175/175 [==============================] - 157s 896ms/step - loss: 0.8003 - accuracy: 0.7151 - val_loss: 0.6689 - val_accuracy: 0.7605
# Epoch 13/15
# 175/175 [==============================] - 159s 906ms/step - loss: 0.7985 - accuracy: 0.6934 - val_loss: 0.6790 - val_accuracy: 0.7419
# Epoch 14/15
# 175/175 [==============================] - 157s 899ms/step - loss: 0.7679 - accuracy: 0.7168 - val_loss: 0.6364 - val_accuracy: 0.7860
# Epoch 15/15
# 175/175 [==============================] - 158s 905ms/step - loss: 0.7764 - accuracy: 0.7157 - val_loss: 0.6362 - val_accuracy: 0.7512
# Epoch 1/40
# 175/175 [==============================] - 246s 1s/step - loss: 1.1280 - accuracy: 0.6819 - val_loss: 0.7659 - val_accuracy: 0.7209
# Epoch 2/40
# 175/175 [==============================] - 213s 1s/step - loss: 0.7431 - accuracy: 0.7334 - val_loss: 0.6450 - val_accuracy: 0.7605
# Epoch 3/40
# 175/175 [==============================] - 219s 1s/step - loss: 0.6349 - accuracy: 0.7626 - val_loss: 0.6424 - val_accuracy: 0.7628
# Epoch 4/40
# 175/175 [==============================] - 216s 1s/step - loss: 0.6209 - accuracy: 0.7672 - val_loss: 0.7988 - val_accuracy: 0.7047
# Epoch 5/40
# 175/175 [==============================] - 220s 1s/step - loss: 0.5612 - accuracy: 0.7912 - val_loss: 0.7241 - val_accuracy: 0.7279
# Epoch 6/40
# 175/175 [==============================] - 221s 1s/step - loss: 0.5120 - accuracy: 0.8015 - val_loss: 0.7144 - val_accuracy: 0.7465
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 7/40
# 175/175 [==============================] - 222s 1s/step - loss: 0.4974 - accuracy: 0.8164 - val_loss: 0.7983 - val_accuracy: 0.7488
# Epoch 8/40
# 175/175 [==============================] - 221s 1s/step - loss: 0.4482 - accuracy: 0.8347 - val_loss: 0.8592 - val_accuracy: 0.7465
# Restoring model weights from the end of the best epoch.
# Epoch 00008: early stopping
# Found 733 validated image filenames.
# FOLD4 - Train Cohen Kappa score: 0.699
