# %%
import os
import cv2
import random
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, cohen_kappa_score
import tensorflow as tf
import keras
from keras.models import Model
from keras import optimizers, applications
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import optimizers
from tensorflow.keras.applications import Xception, NASNetLarge, NASNetMobile, InceptionResNetV2,EfficientNetB0
from keras.layers import Dense, Dropout, GlobalAveragePooling2D, Input

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")

pd.options.display.max_colwidth = 100

# %%
data = pd.read_csv('../input/k-fold-new-data/5-fold.csv')
test = pd.read_csv('../input/k-fold-new-data/test.csv')

data['id_code'] = data['id_code'].apply(lambda x: x + '.jpg')
test['id_code'] = test['id_code'].apply(lambda x: x + '.jpg')

#fold 0
train_fold0 = data[data['fold_0'] == 'train'][['id_code','diagnosis']]
valid_fold0 = data[data['fold_0'] == 'validation'][['id_code','diagnosis']]

#fold 0
train_fold1 = data[data['fold_1'] == 'train'][['id_code','diagnosis']]
valid_fold1 = data[data['fold_1'] == 'validation'][['id_code','diagnosis']]

#fold 0
train_fold2 = data[data['fold_2'] == 'train'][['id_code','diagnosis']]
valid_fold2 = data[data['fold_2'] == 'validation'][['id_code','diagnosis']]

#fold 0
train_fold3 = data[data['fold_3'] == 'train'][['id_code','diagnosis']]
valid_fold3 = data[data['fold_3'] == 'validation'][['id_code','diagnosis']]

#fold 0
train_fold4 = data[data['fold_4'] == 'train'][['id_code','diagnosis']]
valid_fold4 = data[data['fold_4'] == 'validation'][['id_code','diagnosis']]

# %%
# Model parameters
BATCH_SIZE = 10
EPOCHS = 10
WARMUP_EPOCHS = 3
LEARNING_RATE = 1e-4
WARMUP_LEARNING_RATE = 1e-3
HEIGHT = 512
WIDTH = 512
CANAL = 3
N_CLASSES = train_fold0['diagnosis'].nunique()
ES_PATIENCE = 5
RLROP_PATIENCE = 3
DECAY_DROP = 0.5

metric_list = ["accuracy"]

# %%
def train_model(train_fold, valid_fold, fold):
    
    train_fold['diagnosis'] = train_fold['diagnosis'].astype(str)
    valid_fold['diagnosis'] = valid_fold['diagnosis'].astype(str)
    
    datagen=ImageDataGenerator(rescale=1./255, 
                           rotation_range=360,
                           horizontal_flip=True,
                           vertical_flip=True)

    train_generator=datagen.flow_from_dataframe(
                        dataframe=train_fold,
                        directory='../input/resized-2015-2019-blindness-detection-images/resized train 19',
                        x_col="id_code",
                        y_col="diagnosis",
                        class_mode="categorical",
                        batch_size=BATCH_SIZE,
                        target_size=(HEIGHT, WIDTH))

    valid_generator=datagen.flow_from_dataframe(
                        dataframe=valid_fold,
                        directory='../input/resized-2015-2019-blindness-detection-images/resized train 19',
                        x_col="id_code",
                        y_col="diagnosis",
                        class_mode="categorical",
                        batch_size=BATCH_SIZE,
                        target_size=(HEIGHT, WIDTH))

    test_generator=datagen.flow_from_dataframe(  
                       dataframe=test,
                       directory='../input/resized-2015-2019-blindness-detection-images/resized train 19',
                       x_col="id_code",
                       batch_size=1,
                       class_mode=None,
                       shuffle=False,
                       target_size=(HEIGHT, WIDTH))
    
    
    input_tensor = Input(shape=(HEIGHT, WIDTH, CANAL))
    base_model = EfficientNetB0(weights='imagenet', 
                                       include_top=False,
                                       input_tensor=input_tensor)

    x = GlobalAveragePooling2D()(base_model.output)
    x = Dropout(0.5)(x)
    x = Dense(2048, activation='relu')(x)
    x = Dropout(0.5)(x)
    final_output = Dense(5, activation='softmax', name='final_output')(x)
    model = Model(input_tensor, final_output)
    
    for layer in model.layers:
        layer.trainable = False

    for i in range(-5, 0):
        model.layers[i].trainable = True

    metric_list = ["accuracy"]
    optimizer = tf.keras.optimizers.Adam(lr=WARMUP_LEARNING_RATE)
    model.compile(optimizer=optimizer, loss="categorical_crossentropy",  metrics=metric_list)
    
    STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
    STEP_SIZE_VALID = valid_generator.n//valid_generator.batch_size

    history_warmup = model.fit(train_generator,
                                     validation_data=valid_generator,
                                     steps_per_epoch=STEP_SIZE_TRAIN,
                                     validation_steps=STEP_SIZE_VALID,
                                     epochs=15,
                                     verbose=1).history
    
    for layer in model.layers:
        layer.trainable = True

    es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
    rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-6, verbose=1)

    callback_list = [es, rlrop]
    optimizer = tf.keras.optimizers.Adam(lr=LEARNING_RATE)
    model.compile(optimizer=optimizer, loss="categorical_crossentropy",  metrics=metric_list)
    
    history_finetunning = model.fit_generator(generator=train_generator,
                                          steps_per_epoch=STEP_SIZE_TRAIN,
                                          validation_data=valid_generator,
                                          validation_steps=STEP_SIZE_VALID,
                                          epochs=40,
                                          callbacks=callback_list,
                                          verbose=1).history
    
    model.save('EfficientNetB0-'+fold+'sim1.h5')
    
    history = {'loss': history_warmup['loss'] + history_finetunning['loss'], 
               'val_loss': history_warmup['val_loss'] + history_finetunning['val_loss'], 
               'acc': history_warmup['accuracy'] + history_finetunning['accuracy'], 
               'val_acc': history_warmup['val_accuracy'] + history_finetunning['val_accuracy']}

    sns.set_style("whitegrid")
    fig, (ax1, ax2) = plt.subplots(2, 1, sharex='col', figsize=(20, 14))

    ax1.plot(history['loss'], label='Train loss')
    ax1.plot(history['val_loss'], label='Validation loss')
    ax1.legend(loc='best')
    ax1.set_title('Loss')
    plt.ylim([0,1])
    ax2.plot(history['acc'], label='Train Accuracy')
    ax2.plot(history['val_acc'], label='Validation Accuracy')
    ax2.legend(loc='best')
    ax2.set_title('Accuracy')
    ax2.set_ylim([0,1])
    plt.xlabel('Epochs')


    sns.despine()
    fig.savefig('acc-loss-'+fold)
    
    complete_datagen = ImageDataGenerator(rescale=1./255)
    complete_generator = complete_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "../input/resized-2015-2019-blindness-detection-images/resized train 19",
        x_col="id_code",
        target_size=(HEIGHT, WIDTH),
        batch_size=1,
        shuffle=False,
        class_mode=None)

    STEP_SIZE_COMPLETE = complete_generator.n//complete_generator.batch_size
    train_preds = model.predict_generator(complete_generator, steps=STEP_SIZE_COMPLETE)
    train_preds = [np.argmax(pred) for pred in train_preds]

    
    labels = ['0 - No DR', '1 - Mild', '2 - Moderate', '3 - Severe', '4 - Proliferative DR']
    cnf_matrix = confusion_matrix(test['diagnosis'].astype('int'), train_preds)
    cnf_matrix_norm = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    df_cm = pd.DataFrame(cnf_matrix_norm, index=labels, columns=labels)
    plt.figure(figsize=(16, 7))
    heatmap = sns.heatmap(df_cm, annot=True, fmt='.2f', cmap="Blues")
    heatmap = heatmap.get_figure()
    heatmap.savefig('heatmap-'+fold)
    
    print(fold+" - Train Cohen Kappa score: %.3f" % cohen_kappa_score(train_preds, test['diagnosis'].astype('int'), weights='quadratic'))

# %%
train_model(train_fold0, valid_fold0, 'FOLD0')
train_model(train_fold1, valid_fold1, 'FOLD1')
train_model(train_fold2, valid_fold2, 'FOLD2')
train_model(train_fold3, valid_fold3, 'FOLD3')
train_model(train_fold4, valid_fold4, 'FOLD4')
# Out:
# Found 1757 validated image filenames belonging to 5 classes.
# Found 440 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames.
# 2022-07-22 12:27:28.718974: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-22 12:27:28.836482: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-22 12:27:28.837388: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-22 12:27:28.838873: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-22 12:27:28.840171: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-22 12:27:28.840853: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-22 12:27:28.841521: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-22 12:27:31.132824: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-22 12:27:31.133744: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-22 12:27:31.134490: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-22 12:27:31.135113: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16711680/16705208 [==============================] - 0s 0us/step
# 16719872/16705208 [==============================] - 0s 0us/step
# 2022-07-22 12:27:34.148715: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/15
# 2022-07-22 12:27:40.629504: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 175/175 [==============================] - 166s 882ms/step - loss: 1.3877 - accuracy: 0.4677 - val_loss: 1.3267 - val_accuracy: 0.5000
# Epoch 2/15
# 175/175 [==============================] - 138s 791ms/step - loss: 1.3342 - accuracy: 0.4888 - val_loss: 1.3187 - val_accuracy: 0.5000
# Epoch 3/15
# 175/175 [==============================] - 140s 798ms/step - loss: 1.3301 - accuracy: 0.4928 - val_loss: 1.2951 - val_accuracy: 0.5000
# Epoch 4/15
# 175/175 [==============================] - 139s 794ms/step - loss: 1.3180 - accuracy: 0.4934 - val_loss: 1.2974 - val_accuracy: 0.5000
# Epoch 5/15
# 175/175 [==============================] - 138s 792ms/step - loss: 1.3218 - accuracy: 0.4991 - val_loss: 1.3105 - val_accuracy: 0.5000
# Epoch 6/15
# 175/175 [==============================] - 138s 788ms/step - loss: 1.3218 - accuracy: 0.4997 - val_loss: 1.2965 - val_accuracy: 0.5000
# Epoch 7/15
# 175/175 [==============================] - 138s 789ms/step - loss: 1.3160 - accuracy: 0.4980 - val_loss: 1.2916 - val_accuracy: 0.5000
# Epoch 8/15
# 175/175 [==============================] - 139s 792ms/step - loss: 1.3166 - accuracy: 0.5014 - val_loss: 1.2912 - val_accuracy: 0.5000
# Epoch 9/15
# 175/175 [==============================] - 139s 793ms/step - loss: 1.3111 - accuracy: 0.5009 - val_loss: 1.3013 - val_accuracy: 0.5000
# Epoch 10/15
# 175/175 [==============================] - 139s 792ms/step - loss: 1.3143 - accuracy: 0.5020 - val_loss: 1.2929 - val_accuracy: 0.5000
# Epoch 11/15
# 175/175 [==============================] - 139s 792ms/step - loss: 1.3161 - accuracy: 0.4997 - val_loss: 1.2946 - val_accuracy: 0.5000
# Epoch 12/15
# 175/175 [==============================] - 139s 794ms/step - loss: 1.3186 - accuracy: 0.4986 - val_loss: 1.2929 - val_accuracy: 0.5000
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 17/40
# 175/175 [==============================] - 168s 955ms/step - loss: 0.3035 - accuracy: 0.8838 - val_loss: 11.4515 - val_accuracy: 0.5114
# Epoch 18/40
# 175/175 [==============================] - 167s 951ms/step - loss: 0.3180 - accuracy: 0.8804 - val_loss: 3.9480 - val_accuracy: 0.5023
# Restoring model weights from the end of the best epoch.
# Epoch 00018: early stopping
# Found 733 validated image filenames.
# FOLD0 - Train Cohen Kappa score: 0.719
# Found 1757 validated image filenames belonging to 5 classes.
# Found 440 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames.
# Epoch 1/15
# 175/175 [==============================] - 151s 841ms/step - loss: 1.3937 - accuracy: 0.4585 - val_loss: 1.3008 - val_accuracy: 0.5000
# Epoch 2/15
# 175/175 [==============================] - 143s 815ms/step - loss: 1.3459 - accuracy: 0.4768 - val_loss: 1.3093 - val_accuracy: 0.5000
# Epoch 3/15
# 175/175 [==============================] - 142s 810ms/step - loss: 1.3213 - accuracy: 0.4963 - val_loss: 1.3070 - val_accuracy: 0.5000
# Epoch 4/15
# 175/175 [==============================] - 145s 825ms/step - loss: 1.3196 - accuracy: 0.4986 - val_loss: 1.2971 - val_accuracy: 0.5000
# Epoch 5/15
# 175/175 [==============================] - 144s 819ms/step - loss: 1.3211 - accuracy: 0.4974 - val_loss: 1.2977 - val_accuracy: 0.5000
# Epoch 6/15
# 175/175 [==============================] - 146s 831ms/step - loss: 1.3175 - accuracy: 0.4986 - val_loss: 1.2955 - val_accuracy: 0.5000
# Epoch 7/15
# 175/175 [==============================] - 148s 843ms/step - loss: 1.3190 - accuracy: 0.4974 - val_loss: 1.3084 - val_accuracy: 0.5000
# Epoch 8/15
# 175/175 [==============================] - 148s 845ms/step - loss: 1.3105 - accuracy: 0.4986 - val_loss: 1.2987 - val_accuracy: 0.5000
# Epoch 9/15
# 175/175 [==============================] - 148s 844ms/step - loss: 1.3172 - accuracy: 0.4986 - val_loss: 1.3064 - val_accuracy: 0.5000
# Epoch 10/15
# 175/175 [==============================] - 148s 844ms/step - loss: 1.3143 - accuracy: 0.4991 - val_loss: 1.3226 - val_accuracy: 0.5000
# Epoch 11/15
# 175/175 [==============================] - 150s 853ms/step - loss: 1.3115 - accuracy: 0.4997 - val_loss: 1.2974 - val_accuracy: 0.5000
# Epoch 12/15
# 175/175 [==============================] - 150s 854ms/step - loss: 1.3056 - accuracy: 0.4980 - val_loss: 1.2944 - val_accuracy: 0.5000
# Epoch 13/15
# 175/175 [==============================] - 150s 853ms/step - loss: 1.3161 - accuracy: 0.5009 - val_loss: 1.2980 - val_accuracy: 0.5000
# Epoch 14/15
# 175/175 [==============================] - 149s 848ms/step - loss: 1.3161 - accuracy: 0.4997 - val_loss: 1.2953 - val_accuracy: 0.5000
# Epoch 15/15
# 175/175 [==============================] - 150s 853ms/step - loss: 1.3071 - accuracy: 0.5014 - val_loss: 1.2985 - val_accuracy: 0.5000
# Epoch 1/40
# 175/175 [==============================] - 179s 974ms/step - loss: 0.9094 - accuracy: 0.6811 - val_loss: 1.4135 - val_accuracy: 0.5000
# Epoch 2/40
# 175/175 [==============================] - 168s 958ms/step - loss: 0.7037 - accuracy: 0.7453 - val_loss: 1.2963 - val_accuracy: 0.5000
# Epoch 3/40
# 175/175 [==============================] - 170s 967ms/step - loss: 0.6002 - accuracy: 0.7802 - val_loss: 1.3505 - val_accuracy: 0.5000
# Epoch 4/40
# 175/175 [==============================] - 173s 987ms/step - loss: 0.5678 - accuracy: 0.7865 - val_loss: 1.1231 - val_accuracy: 0.5068
# Epoch 5/40
# 175/175 [==============================] - 168s 960ms/step - loss: 0.5412 - accuracy: 0.8060 - val_loss: 1927.9092 - val_accuracy: 0.4159
# Epoch 6/40
# 175/175 [==============================] - 169s 965ms/step - loss: 0.4702 - accuracy: 0.8077 - val_loss: 166.5790 - val_accuracy: 0.5023
# Epoch 7/40
# 175/175 [==============================] - 169s 967ms/step - loss: 0.4859 - accuracy: 0.8065 - val_loss: 1186.5231 - val_accuracy: 0.4750
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 8/40
# 175/175 [==============================] - 169s 966ms/step - loss: 0.4143 - accuracy: 0.8311 - val_loss: 0.8442 - val_accuracy: 0.7023
# Epoch 9/40
# 175/175 [==============================] - 170s 966ms/step - loss: 0.4058 - accuracy: 0.8523 - val_loss: 1.7813 - val_accuracy: 0.5182
# Epoch 10/40
# 175/175 [==============================] - 169s 963ms/step - loss: 0.3907 - accuracy: 0.8472 - val_loss: 1.6348 - val_accuracy: 0.5023
# Epoch 11/40
# 175/175 [==============================] - 171s 977ms/step - loss: 0.4267 - accuracy: 0.8392 - val_loss: 1.2385 - val_accuracy: 0.6000
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 12/40
# 175/175 [==============================] - 169s 961ms/step - loss: 0.3600 - accuracy: 0.8598 - val_loss: 6.6001 - val_accuracy: 0.5068
# Epoch 13/40
# 175/175 [==============================] - 169s 964ms/step - loss: 0.3398 - accuracy: 0.8649 - val_loss: 1.1447 - val_accuracy: 0.5136
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping
# Found 733 validated image filenames.
# FOLD1 - Train Cohen Kappa score: 0.513
# Found 1758 validated image filenames belonging to 5 classes.
# Found 439 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames.
# Epoch 1/15
# 175/175 [==============================] - 154s 853ms/step - loss: 1.3808 - accuracy: 0.4617 - val_loss: 1.3084 - val_accuracy: 0.5047
# Epoch 2/15
# 175/175 [==============================] - 147s 842ms/step - loss: 1.3419 - accuracy: 0.4743 - val_loss: 1.3193 - val_accuracy: 0.5000
# Epoch 3/15
# 175/175 [==============================] - 148s 847ms/step - loss: 1.3293 - accuracy: 0.4908 - val_loss: 1.3177 - val_accuracy: 0.4977
# Epoch 4/15
# 175/175 [==============================] - 146s 834ms/step - loss: 1.3208 - accuracy: 0.4966 - val_loss: 1.3318 - val_accuracy: 0.4977
# Epoch 5/15
# 175/175 [==============================] - 148s 842ms/step - loss: 1.3218 - accuracy: 0.4994 - val_loss: 1.3432 - val_accuracy: 0.4977
# Epoch 6/15
# 175/175 [==============================] - 147s 841ms/step - loss: 1.3216 - accuracy: 0.4960 - val_loss: 1.3059 - val_accuracy: 0.5023
# Epoch 7/15
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 14/40
# 175/175 [==============================] - 165s 943ms/step - loss: 0.3262 - accuracy: 0.8787 - val_loss: 0.8491 - val_accuracy: 0.7186
# Epoch 15/40
# 175/175 [==============================] - 170s 968ms/step - loss: 0.3234 - accuracy: 0.8753 - val_loss: 1.0461 - val_accuracy: 0.6767
# Restoring model weights from the end of the best epoch.
# Epoch 00015: early stopping
# Found 733 validated image filenames.
# FOLD2 - Train Cohen Kappa score: 0.680
# Found 1758 validated image filenames belonging to 5 classes.
# Found 439 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames.
# Epoch 1/15
# 175/175 [==============================] - 156s 865ms/step - loss: 1.3923 - accuracy: 0.4519 - val_loss: 1.3176 - val_accuracy: 0.5023
# Epoch 2/15
# 175/175 [==============================] - 145s 830ms/step - loss: 1.3392 - accuracy: 0.4737 - val_loss: 1.3282 - val_accuracy: 0.4953
# Epoch 3/15
# 175/175 [==============================] - 145s 827ms/step - loss: 1.3201 - accuracy: 0.4914 - val_loss: 1.2997 - val_accuracy: 0.4953
# Epoch 4/15
# 175/175 [==============================] - 145s 827ms/step - loss: 1.3193 - accuracy: 0.4983 - val_loss: 1.3055 - val_accuracy: 0.4977
# Epoch 5/15
# 175/175 [==============================] - 147s 836ms/step - loss: 1.3181 - accuracy: 0.4989 - val_loss: 1.2958 - val_accuracy: 0.5023
# Epoch 6/15
# 175/175 [==============================] - 146s 832ms/step - loss: 1.3232 - accuracy: 0.4920 - val_loss: 1.2957 - val_accuracy: 0.5023
# Epoch 7/15
# 175/175 [==============================] - 147s 838ms/step - loss: 1.3149 - accuracy: 0.4960 - val_loss: 1.3032 - val_accuracy: 0.4953
# Epoch 8/15
# 175/175 [==============================] - 147s 842ms/step - loss: 1.3137 - accuracy: 0.5000 - val_loss: 1.2904 - val_accuracy: 0.4977
# Epoch 9/15
# 175/175 [==============================] - 147s 839ms/step - loss: 1.3205 - accuracy: 0.4983 - val_loss: 1.2954 - val_accuracy: 0.4977
# Epoch 10/15
# 175/175 [==============================] - 145s 832ms/step - loss: 1.3189 - accuracy: 0.5000 - val_loss: 1.2985 - val_accuracy: 0.5000
# Epoch 11/15
# 175/175 [==============================] - 146s 830ms/step - loss: 1.3091 - accuracy: 0.5006 - val_loss: 1.2973 - val_accuracy: 0.4977
# Epoch 12/15
# 175/175 [==============================] - 146s 834ms/step - loss: 1.3120 - accuracy: 0.5006 - val_loss: 1.3036 - val_accuracy: 0.4953
# Epoch 13/15
# 175/175 [==============================] - 146s 836ms/step - loss: 1.3186 - accuracy: 0.4994 - val_loss: 1.2921 - val_accuracy: 0.4977
# Epoch 14/15
# 175/175 [==============================] - 146s 832ms/step - loss: 1.3068 - accuracy: 0.5006 - val_loss: 1.2945 - val_accuracy: 0.4953
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 17/40
# 175/175 [==============================] - 172s 982ms/step - loss: 0.3296 - accuracy: 0.8839 - val_loss: 1.2674 - val_accuracy: 0.6698
# Epoch 18/40
# 175/175 [==============================] - 182s 1s/step - loss: 0.3060 - accuracy: 0.8816 - val_loss: 0.9667 - val_accuracy: 0.7837
# Epoch 19/40
# 175/175 [==============================] - 170s 972ms/step - loss: 0.3236 - accuracy: 0.8776 - val_loss: 1.2363 - val_accuracy: 0.6302
# Epoch 20/40
# 175/175 [==============================] - 172s 977ms/step - loss: 0.3110 - accuracy: 0.8839 - val_loss: 1.2009 - val_accuracy: 0.7116
# Epoch 21/40
# 175/175 [==============================] - 169s 966ms/step - loss: 0.2912 - accuracy: 0.8890 - val_loss: 1.4334 - val_accuracy: 0.2628
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 22/40
# 175/175 [==============================] - 170s 970ms/step - loss: 0.2924 - accuracy: 0.8879 - val_loss: 1.1400 - val_accuracy: 0.6721
# Epoch 23/40
# 175/175 [==============================] - 169s 966ms/step - loss: 0.2974 - accuracy: 0.8890 - val_loss: 0.9806 - val_accuracy: 0.8000
# Restoring model weights from the end of the best epoch.
# Epoch 00023: early stopping
# Found 733 validated image filenames.
# FOLD3 - Train Cohen Kappa score: 0.782
# Found 1758 validated image filenames belonging to 5 classes.
# Found 439 validated image filenames belonging to 5 classes.
# Found 733 validated image filenames.
# Epoch 1/15
# 175/175 [==============================] - 155s 863ms/step - loss: 1.3763 - accuracy: 0.4680 - val_loss: 1.3357 - val_accuracy: 0.4977
# Epoch 2/15
# 175/175 [==============================] - 150s 851ms/step - loss: 1.3415 - accuracy: 0.4874 - val_loss: 1.2977 - val_accuracy: 0.5047
# Epoch 3/15
# 175/175 [==============================] - 149s 852ms/step - loss: 1.3286 - accuracy: 0.4886 - val_loss: 1.3045 - val_accuracy: 0.4977
# Epoch 4/15
# 175/175 [==============================] - 148s 847ms/step - loss: 1.3285 - accuracy: 0.4949 - val_loss: 1.2955 - val_accuracy: 0.5000
# Epoch 5/15
# 175/175 [==============================] - 150s 856ms/step - loss: 1.3235 - accuracy: 0.4977 - val_loss: 1.2831 - val_accuracy: 0.5023
# Epoch 6/15
# 175/175 [==============================] - 149s 850ms/step - loss: 1.3241 - accuracy: 0.4937 - val_loss: 1.3066 - val_accuracy: 0.4977
# Epoch 7/15
# 175/175 [==============================] - 150s 855ms/step - loss: 1.3159 - accuracy: 0.5006 - val_loss: 1.2936 - val_accuracy: 0.5000
# Epoch 8/15
# 175/175 [==============================] - 149s 852ms/step - loss: 1.3111 - accuracy: 0.4983 - val_loss: 1.2976 - val_accuracy: 0.4977
# Epoch 9/15
# 175/175 [==============================] - 151s 863ms/step - loss: 1.3103 - accuracy: 0.5000 - val_loss: 1.2871 - val_accuracy: 0.5047
# Epoch 10/15
# 175/175 [==============================] - 151s 864ms/step - loss: 1.3251 - accuracy: 0.4977 - val_loss: 1.3031 - val_accuracy: 0.4977
# Epoch 11/15
# 175/175 [==============================] - 148s 849ms/step - loss: 1.3145 - accuracy: 0.4994 - val_loss: 1.2984 - val_accuracy: 0.4977
# Epoch 12/15
# 175/175 [==============================] - 148s 845ms/step - loss: 1.3141 - accuracy: 0.5006 - val_loss: 1.3011 - val_accuracy: 0.5000
# Epoch 13/15
# 175/175 [==============================] - 150s 855ms/step - loss: 1.3096 - accuracy: 0.5006 - val_loss: 1.2980 - val_accuracy: 0.5000
# Epoch 14/15
# 175/175 [==============================] - 149s 849ms/step - loss: 1.3098 - accuracy: 0.5000 - val_loss: 1.2919 - val_accuracy: 0.5000
# Epoch 15/15
# 175/175 [==============================] - 150s 861ms/step - loss: 1.3158 - accuracy: 0.4994 - val_loss: 1.3056 - val_accuracy: 0.4953
# Epoch 1/40
# 175/175 [==============================] - 186s 994ms/step - loss: 0.9814 - accuracy: 0.6693 - val_loss: 1.3724 - val_accuracy: 0.5047
# Epoch 2/40
# 175/175 [==============================] - 171s 977ms/step - loss: 0.6914 - accuracy: 0.7374 - val_loss: 1.4118 - val_accuracy: 0.4953
# Epoch 3/40
# 175/175 [==============================] - 170s 970ms/step - loss: 0.6130 - accuracy: 0.7677 - val_loss: 1.2918 - val_accuracy: 0.5000
# Epoch 4/40
# 175/175 [==============================] - 171s 976ms/step - loss: 0.5627 - accuracy: 0.7780 - val_loss: 396.6722 - val_accuracy: 0.4395
# Epoch 5/40
# 175/175 [==============================] - 171s 978ms/step - loss: 0.5081 - accuracy: 0.8003 - val_loss: 72.0537 - val_accuracy: 0.4581
# Epoch 6/40
# 175/175 [==============================] - 166s 950ms/step - loss: 0.4865 - accuracy: 0.8129 - val_loss: 1.2262 - val_accuracy: 0.6023
# Epoch 7/40
# 175/175 [==============================] - 164s 940ms/step - loss: 0.4761 - accuracy: 0.8278 - val_loss: 1.3737 - val_accuracy: 0.3791
# Epoch 8/40
# 175/175 [==============================] - 167s 955ms/step - loss: 0.4467 - accuracy: 0.8181 - val_loss: 1.4367 - val_accuracy: 0.4093
# Epoch 9/40
# 175/175 [==============================] - 165s 944ms/step - loss: 0.4156 - accuracy: 0.8404 - val_loss: 29809.1113 - val_accuracy: 0.4953
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 10/40
# 175/175 [==============================] - 172s 980ms/step - loss: 0.3748 - accuracy: 0.8570 - val_loss: 1.0126 - val_accuracy: 0.6581
# Epoch 11/40
# 175/175 [==============================] - 166s 947ms/step - loss: 0.3579 - accuracy: 0.8576 - val_loss: 284.3452 - val_accuracy: 0.5140
# Epoch 12/40
# 175/175 [==============================] - 166s 946ms/step - loss: 0.3595 - accuracy: 0.8547 - val_loss: 0.7329 - val_accuracy: 0.7395
# Epoch 13/40
# 175/175 [==============================] - 166s 947ms/step - loss: 0.3576 - accuracy: 0.8558 - val_loss: 1.8850 - val_accuracy: 0.5163
# Epoch 14/40
# 175/175 [==============================] - 173s 985ms/step - loss: 0.3438 - accuracy: 0.8661 - val_loss: 1.3634 - val_accuracy: 0.6256
# Epoch 15/40
# 175/175 [==============================] - 164s 940ms/step - loss: 0.3247 - accuracy: 0.8696 - val_loss: 65.5679 - val_accuracy: 0.4907
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 16/40
# 175/175 [==============================] - 165s 943ms/step - loss: 0.3081 - accuracy: 0.8781 - val_loss: 1.0057 - val_accuracy: 0.6791
# Epoch 17/40
# 175/175 [==============================] - 172s 980ms/step - loss: 0.3072 - accuracy: 0.8787 - val_loss: 0.9428 - val_accuracy: 0.7465
# Restoring model weights from the end of the best epoch.
# Epoch 00017: early stopping
# Found 733 validated image filenames.
# FOLD4 - Train Cohen Kappa score: 0.760
